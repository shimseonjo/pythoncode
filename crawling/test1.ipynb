# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '[{"id":"12917628714","type":"PushEvent","actor":{"id":68013390,"login":"rgpihlstrom","display_login":"rgpihlstrom","gravatar_id":"","url":"https://api.github.com/users/rgpihlstrom","avatar_url":"https://avatars.githubusercontent.com/u/68013390?"},"repo":{"id":279976757,"name":"rgpihlstrom/conditionals-python-lab-data-science-intro-000","url":"https://api.github.com/repos/rgpihlstrom/conditionals-python-lab-data-science-intro-000"},"payload":{"push_id":5380826541,"size":1,"distinct_size":1,"ref":"refs/heads/wip","head":"57a30b7953240f77fd62d673c620077c55060455","before":"4af70f9b628da647377155974067f1eac24c0886","commits":[{"sha":"57a30b7953240f77fd62d673c620077c55060455","author":{"email":"rgpihlstrom@yahoo.com","name":"Russell Pihlstrom"},"message":"Automatically backed up by Learn","distinct":true,"url":"https://api.github.com/repos/rgpihlstrom/conditionals-python-lab-data-science-intro-000/commits/57a30b7953240f77fd62d673c620077c55060455"}]},"public":true,"created_at":"2020-07-16
# ...

# %%
r=requests.get('http://naver.com')

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '\n<!doctype html>                <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양
# ...

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

# %%
r = requests.get('https://httpbin.org/get', params=payload)

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{\n  "args": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.22.0", \n    "X-Amzn-Trace-Id": "Root=1-5f0f9f10-a6acdec0975940c4b6300ed4"\n  }, \n  "origin": "1.221.125.150", \n  "url": "https://httpbin.org/get?key1=value1&key2=value2"\n}\n'

# %%
r.url
# Out:
# 'https://httpbin.org/get?key1=value1&key2=value2'

# %%
r= requests.get('http://localhost:8890/content/hong')

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '<!doctype html>\n<html lang="en">\n  <head>\n    <!-- Required meta tags -->\n<meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n<!-- Bootstrap CSS -->\n<link href="https://fonts.googleapis.com/css2?family=Cute+Font&display=swap" rel="stylesheet">\n<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css" integrity="sha384-GJzZqFGwb1QTTN6wy59ffF1BuGJpLSa9DkKMp0DgiMDm4iYMj70gZWKYbI706tWS" crossorigin="anonymous">\n<link href="https://fonts.googleapis.com/css?family=Do+Hyeon" rel="stylesheet">\n<script src="https://code.jquery.com/jquery-3.3.1.slim.min.js" integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo" crossorigin="anonymous"></script>\n<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.6/umd/popper.min.js" integrity="sha384-wHAiFfRlMFy6i5SRaxvfOCifBUQy1xHdJ/yoi7FRNXMRBu5WHdZYu1hA6ZOblgut" crossorigin="anonymous"></script>\n<scr
# ...

# %%
r.url
# Out:
# 'http://localhost:8890/l'

# %%
r.history
# Out:
# []

# %%
r.is_redirect
# Out:
# False

# %%
r.status_code
# Out:
# 404

# %%
data={'sm':'top_hty','fbm':'1','ie':'utf8','query':'대구'}

# %%
r= requests.get('https://search.naver.com/search.naver',params=data)

# %%
r
# Out:
# <Response [200]>

# %%
r.url
# Out:
# 'https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EB%8C%80%EA%B5%AC'

# %%
r.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="대구 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'대구\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'대구\'의 네이버 통합검색 결과입니다."> <title>대구 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200528.css"> <link rel="stylesheet" type="text/css" href="
# ...

# %%
r.encoding
# Out:
# 'UTF-8'

# %%
r.headers
# Out:
# {'Date': 'Thu, 16 Jul 2020 00:40:48 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'page_uid=Uw+AZsp0Yihssgp9/2wssssssNV-298694; path=/; domain=.naver.com, _naver_usersession_=p5tBNu3TO6lop7Oeg0ZDKw==; path=/; expires=Thu, 16-Jul-20 00:45:48 GMT; domain=.naver.com, nx_ssl=2; Domain=.naver.com; Path=/; Expires=Sat, 15-Aug-2020 00:40:48 GMT;', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; report=/p/er/post/xss', 'Cache-Control': 'no-cache, no-store, must-revalidate, max-age=0', 'Pragma': 'no-cache', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Server': 'nxg'}

# %%
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='_naver_usersession_', value='p5tBNu3TO6lop7Oeg0ZDKw==', port=None, port_specified=False, domain='.naver.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1594860348, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='nx_ssl', value='2', port=None, port_specified=False, domain='.naver.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1597452048, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='page_uid', value='Uw+AZsp0Yihssgp9/2wssssssNV-298694', port=None, port_specified=False, domain='.naver.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}

# %%
r = requests.get('https://httpbin.org/get', params=payload)

# %%
r.url
# Out:
# 'https://httpbin.org/get?key1=value1&key2=value2&key2=value3'

# %%
r=requests.get('https://postfiles.pstatic.net/20130319_100/daol01_1363651931964WhvVm_JPEG/%BB%E7%B6%FB%B1%DB%B1%CD%2C%BF%EC%C1%A4%B1%DB%B1%CD%2C%C1%C1%C0%BA%B1%DB%B1%CD%2C%B0%A8%B5%BF%B1%DB%B1%CD%2C%B9%E8%B0%E6%C8%AD%B8%E9%2C%B9%E8%B0%E6%BB%E7%C1%F8%2C%B0%ED%B9%E9%B1%DB%B1%CD_%284%29.jpg?type=w2')

# %%
from PIL import Image
from io import BytesIO

# %%
i = Image.open(BytesIO(r.content))

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=743x522 at 0x243D494A808>

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.content
# Out:
# b'[{"id":"12917783528","type":"PushEvent","actor":{"id":56033691,"login":"coula3","display_login":"coula3","gravatar_id":"","url":"https://api.github.com/users/coula3","avatar_url":"https://avatars.githubusercontent.com/u/56033691?"},"repo":{"id":212112017,"name":"coula3/learn-co-sandbox","url":"https://api.github.com/repos/coula3/learn-co-sandbox"},"payload":{"push_id":5380908295,"size":1,"distinct_size":1,"ref":"refs/heads/wip","head":"cca7a94e9f8dc874c91db247592252c2ac9e3fef","before":"9c3d3080253ef936cf76bd88c481793e6df395ac","commits":[{"sha":"cca7a94e9f8dc874c91db247592252c2ac9e3fef","author":{"email":"aaacoulson@gmail.com","name":"Alvin Coulson"},"message":"Automatically backed up by Learn","distinct":true,"url":"https://api.github.com/repos/coula3/learn-co-sandbox/commits/cca7a94e9f8dc874c91db247592252c2ac9e3fef"}]},"public":true,"created_at":"2020-07-16T00:48:31Z"},{"id":"12917783522","type":"PushEvent","actor":{"id":65628325,"login":"hyudnp","display_login":"hyudnp","gravat
# ...

# %%
r.text
# Out:
# '[{"id":"12917783528","type":"PushEvent","actor":{"id":56033691,"login":"coula3","display_login":"coula3","gravatar_id":"","url":"https://api.github.com/users/coula3","avatar_url":"https://avatars.githubusercontent.com/u/56033691?"},"repo":{"id":212112017,"name":"coula3/learn-co-sandbox","url":"https://api.github.com/repos/coula3/learn-co-sandbox"},"payload":{"push_id":5380908295,"size":1,"distinct_size":1,"ref":"refs/heads/wip","head":"cca7a94e9f8dc874c91db247592252c2ac9e3fef","before":"9c3d3080253ef936cf76bd88c481793e6df395ac","commits":[{"sha":"cca7a94e9f8dc874c91db247592252c2ac9e3fef","author":{"email":"aaacoulson@gmail.com","name":"Alvin Coulson"},"message":"Automatically backed up by Learn","distinct":true,"url":"https://api.github.com/repos/coula3/learn-co-sandbox/commits/cca7a94e9f8dc874c91db247592252c2ac9e3fef"}]},"public":true,"created_at":"2020-07-16T00:48:31Z"},{"id":"12917783522","type":"PushEvent","actor":{"id":65628325,"login":"hyudnp","display_login":"hyudnp","gravata
# ...

# %%
j=r.json()

# %%
j[0]['repo']['id']
# Out:
# 212112017

# %%
j
# Out:
# [{'id': '12917783528',
#   'type': 'PushEvent',
#   'actor': {'id': 56033691,
#    'login': 'coula3',
#    'display_login': 'coula3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/coula3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56033691?'},
#   'repo': {'id': 212112017,
#    'name': 'coula3/learn-co-sandbox',
#    'url': 'https://api.github.com/repos/coula3/learn-co-sandbox'},
#   'payload': {'push_id': 5380908295,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': 'cca7a94e9f8dc874c91db247592252c2ac9e3fef',
#    'before': '9c3d3080253ef936cf76bd88c481793e6df395ac',
#    'commits': [{'sha': 'cca7a94e9f8dc874c91db247592252c2ac9e3fef',
#      'author': {'email': 'aaacoulson@gmail.com', 'name': 'Alvin Coulson'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/coula3/learn-co-sandbox/commits/cca7a94e9f8dc874c91db247592252c2ac9e3fef'}]},
# ...

# %%
url = 'https://api.github.com/some/endpoint'

# %%
headers = {'user-agent': 'my-app/0.0.1'}

# %%
r = requests.get(url)

# %%
r
# Out:
# <Response [404]>

# %%
r.url
# Out:
# 'https://api.github.com/some/endpoint'

# %%
r.headers
# Out:
# {'date': 'Thu, 16 Jul 2020 01:14:25 GMT', 'content-type': 'application/json; charset=utf-8', 'server': 'GitHub.com', 'status': '404 Not Found', 'x-github-media-type': 'github.v3; format=json', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'access-control-allow-origin': '*', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'x-frame-options': 'deny', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'content-security-policy': "default-src 'none'", 'vary': 'Accept-Encoding, Accept, X-Requested-With', 'content-encoding': 'gzip', 'X-Ratelimit-Limit': '60', 'X-Ratelimit-Remaining': '24', 'X-Ratelimit-Reset': '1594864933', 'Content-Length': '96', 'X-GitHub-Request-I
# ...

# %%
data={'userid':'ho'}
r=requests.post('http://localhost:8890/ajaxlist',data=data)

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# [{'useradd': '부산',
#   'userage': 33,
#   'usergender': 'male',
#   'userid': 'hong',
#   'usermail': 'shim@gmail.com',
#   'username': 'hong',
#   'userpw': '1111',
#   'usertel': '010-1111-2222'},
#  {'useradd': '부산',
#   'userage': 33,
#   'usergender': 'female',
#   'userid': 'hong1111',
#   'usermail': 'shim@gmail.com',
#   'username': 'shim',
#   'userpw': '',
#   'usertel': '010-1111-2222'}]

# %%
r.url
# Out:
# 'http://localhost:8890/ajaxlist'

# %%
r.headers
# Out:
# {'Content-Type': 'application/json', 'Content-Length': '456', 'Server': 'Werkzeug/1.0.0 Python/3.7.6', 'Date': 'Thu, 16 Jul 2020 01:21:15 GMT'}

# %%
data={'useradd': '부산',
  'userage': 33,
  'usergender': 'female',
  'userid': 'gong2222',
  'usermail': 'shim@gmail.com',
  'username': 'shim',
  'userpw': '11111',
  'usertel': '010-1111-2222'}

# %%
r=requests.post('http://localhost:8890/usersform',data=data,allow_redirects=False)

# %%
r
# Out:
# <Response [302]>

# %%
r.url
# Out:
# 'http://localhost:8890/usersform'

# %%
r.history
# Out:
# []

# %%
files = {'file': open('C:/Users/admin/Downloads/csv_exam.csv', 'rb')}
r=requests.post('http://localhost:8890/fileupload',files=files)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# ...
