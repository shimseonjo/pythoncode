# %%
url = 'https://httpbin.org/post'

# %%
files = {'file': open('test.txt', 'rb')}

# %%
import requests
r = requests.post(url, files=files)

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {'file': 'test'},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '148',
#   'Content-Type': 'multipart/form-data; boundary=bd5b3e0a5bdbb2e4a03ecf546aad86aa',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f0fb196-ec20d2465b4c82b1d27b990a'},
#  'json': None,
#  'origin': '1.221.125.150',
#  'url': 'https://httpbin.org/post'}

# %%
url = 'http://example.com/some/cookie/setting/url'

# %%
r = requests.get(url)

# %%
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
url = 'https://httpbin.org/cookies'

# %%
cookies = dict(cookies_are='working')

# %%
r = requests.get(url, cookies=cookies)

# %%
r.text
# Out:
# '{\n  "cookies": {\n    "cookies_are": "working"\n  }\n}\n'

# %%
jar = requests.cookies.RequestsCookieJar()

# %%
jar.set('tasty_cookie', 'yum', domain='httpbin.org', path='/cookies')
# Out:
# Cookie(version=0, name='tasty_cookie', value='yum', port=None, port_specified=False, domain='httpbin.org', domain_specified=True, domain_initial_dot=False, path='/cookies', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)

# %%
jar.set('gross_cookie', 'blech', domain='httpbin.org', path='/elsewhere')
# Out:
# Cookie(version=0, name='gross_cookie', value='blech', port=None, port_specified=False, domain='httpbin.org', domain_specified=True, domain_initial_dot=False, path='/elsewhere', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)

# %%
url = 'https://httpbin.org/cookies'

# %%
r = requests.get(url, cookies=jar)

# %%
r.text
# Out:
# '{\n  "cookies": {\n    "tasty_cookie": "yum"\n  }\n}\n'

# %%
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
from urllib import request

# %%
with request.urlopen('http://python.org/') as r:
    the_page = r.read()
    print(the_page)
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->\n\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">\n\n    <meta name="application-name" content="Python.org">\n    <meta name="msapplication-tooltip" content="The official home of the Python Programming Language">\n    <meta name="apple-mobile-web-app-title" content="Python.org">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="
# ...

# %%
import urllib.request
req = urllib.request.Request('http://naver.com')

# %%
req

# %%
r = urllib.request.urlopen(req)

# %%
r

# %%
r.read()
# Out:
# b'\n<!doctype html>                <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xe
# ...

# %% [raw]
# https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EB%82%A0%EC%94%A8

# %%
import urllib.parse
import urllib.request

# %%
url = 'https://search.naver.com/search.naver'

# %%
values={'sm':'top_hty','fbm':'1','ie':'utf8','query':'날씨'}

# %%
dat = urllib.parse.urlencode(values)

# %%
re = urllib.request.urlopen(url+'?'+dat)

# %%
re

# %%
re.read()
# Out:
# b'<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="\xeb\x82\xa0\xec\x94\xa8 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\xeb\x82\xa0\xec\x94\xa8\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <meta name="description" lang="ko" content="\'\xeb\x82\xa0\xec\x94\xa8\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <title>\xeb\x82\xa0
# ...
