# %%
# %matplotlib inline
import urllib.request 
import json, datetime, time
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import warnings
warnings.filterwarnings('ignore')

# %%
# 일별 박스오피스
def cineBoxInfo():
    #오늘 날짜를 가져와서 사용할 형식으로 만든다.
    movieDate=time.strftime('%Y%m%d', time.localtime(time.time()))
    
    cine=[]
    for i in range(0,30):
        #자료는 매일 갱신되며 갱신 시간이전에 요청시 내용이 비어 있음.
        #반복 함수 마지막에 날짜를 줄이는 함수를 사용한다.
        #str -> date
        datetime_obj = datetime.datetime.strptime(movieDate,"%Y%m%d").date()

        # 1일 혹은 1주일씩 시간을 줄여간다.
        datetime_obj_tmp = datetime_obj - datetime.timedelta(days=1)  #weeks=1
        
        #date -> str
        movieDate = datetime_obj_tmp.strftime("%Y%m%d")
        print(movieDate, end=" ")
                
        url = f"http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=66e652e1d2656b42f10d93c91e0295e4&targetDt={movieDate}"
        response =urllib.request.urlopen(url)
        #print(response)
        
        rescode = response.getcode()
        if(rescode == 200):
            responseData = response.read()

        result = json.loads(responseData)
        #print(result)
        pre_result = result["boxOfficeResult"]["dailyBoxOfficeList"]
        #print(pre_result)     
        
        for i in range(0,len(pre_result)):
            pre_result[i]['targetDt']=movieDate
            cine.append(pre_result[i])
      
    print()
    #list->dataframe
    dataframe=pd.DataFrame(cine)
    print(dataframe.columns)
    dataframe.to_csv("cinebox.csv", index = False)
    return dataframe

# %%
# 영화상세정보
def cineInfo(movieCd):
    url = f"http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=66e652e1d2656b42f10d93c91e0295e4&movieCd="+str(movieCd)
    response = urllib.request.urlopen(url)
    text = response.read()
    #print(text)
    d = json.loads(text)
    #print(d)
    movieInfo = d['movieInfoResult']['movieInfo']
    return movieInfo

# %%
cineBoxInfo()
# Out:
# 20200720 20200719 20200718 20200717 20200716 20200715 20200714 20200713 20200712 20200711 20200710 20200709 20200708 20200707 20200706 20200705 20200704 20200703 20200702 20200701 20200630 20200629 20200628 20200627 20200626 20200625 20200624 20200623 20200622 20200621
# Index(['rnum', 'rank', 'rankInten', 'rankOldAndNew', 'movieCd', 'movieNm',
#        'openDt', 'salesAmt', 'salesShare', 'salesInten', 'salesChange',
#        'salesAcc', 'audiCnt', 'audiInten', 'audiChange', 'audiAcc', 'scrnCnt',
#        'showCnt', 'targetDt'],
#       dtype='object')
#     rnum rank rankInten rankOldAndNew   movieCd          movieNm      openDt  \
# 0      1    1         0           OLD  20193450               반도  2020-07-15
# 1      2    2         0           OLD  20193069            #살아있다  2020-06-24
# 2      3    3         0           OLD  20204644  밤쉘: 세상을 바꾼 폭탄선언  2020-07-08
# 3      4    4         1           OLD  20200162          소년시절의 너  2020-07-09
# 4      5    5         1           OLD  20200845             비바리움  2020-07-16
# ..   ...  ...       ...           ...       ...              ...         ...
# 295    6    6         0           OLD  20196702             야구소녀  2020-06-18
# 296    7    7         0           OLD  20205481            에어로너츠  2020-06-10
# 297    8    8         0           OLD  20209463     나의 첫 번째 슈퍼스타  2020-06-10
# 298    9    9         1           OLD  20184842      아이 캔 온리 이매진  2018-06-21
# 299   10   10        -1           OLD  20198890   아이즈 온 미 : 더 무비  2020-06-10
#
#        salesAmt salesShare   salesInten salesChange     salesAcc audiCnt  \
# 0    1183766780       87.7  -2804113320       -70.3  17065939380  141480
# 1      34586820        2.6    -37027380       -51.7  15675513340    4806
# 2      33282220        2.5    -35391720       -51.5   1218120740    4085
# 3      16606000        1.2     -8469800       -33.8    286011800    2021
# 4      10276380        0.8    -10257580         -50     80788380    1250
# ..          ...        ...          ...         ...          ...     ...
# 295    38904340        2.4       518120         1.3    149397880    4310
# 296    31135740        1.9     -6137600       -16.5    636643960    3262
# 297    21903740        1.3     -2283180        -9.4    430842560    2304
# 298     9095480        0.6      1405420        18.3    228396040    1385
# 299    16204500        1.0     -1128500        -6.5    487027000    1247
#
#     audiInten audiChange  audiAcc scrnCnt showCnt  targetDt
# 0     -301684      -68.1  1945520    2258   10778  20200720
# 1       -4384      -47.7  1855485     477    1057  20200720
# 2       -3599      -46.8   143174     459     953  20200720
# 3        -808      -28.6    33373     162     303  20200720
# 4       -1006      -44.6     9320     124     209  20200720
# ..        ...        ...      ...     ...     ...       ...
# 295       102        2.4    17096     254     401  20200621
# 296      -613      -15.8    71614     256     352  20200621
# 297      -211       -8.4    47185     182     238  20200621
# 298       221         19    28932     131     150  20200621
# 299       -88       -6.6    37743      96     106  20200621
#
# [300 rows x 19 columns]

# %%
# 영화코드를 인자로 받아 영화상세정보 리턴
movieInfo = cineInfo(20193450)
movieInfo
# Out:
# {'movieCd': '20193450',
#  'movieNm': '반도',
#  'movieNmEn': 'Peninsula',
#  'movieNmOg': '',
#  'showTm': '115',
#  'prdtYear': '2020',
#  'openDt': '20200715',
#  'prdtStatNm': '개봉',
#  'typeNm': '장편',
#  'nations': [{'nationNm': '한국'}],
#  'genres': [{'genreNm': '액션'}, {'genreNm': '드라마'}],
#  'directors': [{'peopleNm': '연상호', 'peopleNmEn': 'YEON Sang-ho'}],
#  'actors': [{'peopleNm': '강동원',
#    'peopleNmEn': 'GANG Dong-won',
#    'cast': '',
#    'castEn': ''},
#   {'peopleNm': '이정현', 'peopleNmEn': 'LEE Jung-hyun', 'cast': '', 'castEn': ''},
#   {'peopleNm': '이레', 'peopleNmEn': 'LEE Re', 'cast': '', 'castEn': ''},
#   {'peopleNm': '권해효', 'peopleNmEn': 'KWON Hae-hyo', 'cast': '', 'castEn': ''},
#   {'peopleNm': '김민재', 'peopleNmEn': 'KIM Min-jae', 'cast': '', 'castEn': ''},
#   {'peopleNm': '구교환', 'peopleNmEn': 'KOO Kyo-hwan', 'cast': '', 'castEn': ''},
#   {'peopleNm': '김도윤', 'peopleNmEn': 'KIM Do-yoon', 'cast': '', 'castEn': ''},
#   {'peopleNm': '이예원', 'peopleNmEn': 'LEE Ye-won', 'cast': '', 'castEn': ''}],
#  'showTypes': [{'showTypeGroupNm': '2D', 'showTypeNm': '디지털'},
#   {'showTypeGroupNm': '2D', 'showTypeNm': '디지털 영문자막'},
#   {'showTypeGroupNm': '4D', 'showTypeNm': '4D'},
#   {'showTypeGroupNm': 'IMAX', 'showTypeNm': 'IMAX'},
#   {'showTypeGroupNm': 'ScreenX', 'showTypeNm': 'ScreenX'}],
#  'companys': [{'companyCd': '20140808',
#    'companyNm': '(주)영화사레드피터',
#    'companyNmEn': 'REDPETER FILMS Co., Ltd',
#    'companyPartNm': '제작사'},
#   {'companyCd': '20100932',
#    'companyNm': '(주)넥스트엔터테인먼트월드(NEW)',
#    'companyNmEn': 'Next Entertainment World',
#    'companyPartNm': '배급사'},
#   {'companyCd': '20100932',
#    'companyNm': '(주)넥스트엔터테인먼트월드(NEW)',
#    'companyNmEn': 'Next Entertainment World',
#    'companyPartNm': '제공'}],
#  'audits': [{'auditNo': '2020-MF01179 ', 'watchGradeNm': '15세이상관람가'}],
#  'staffs': [{'peopleNm': '이동하',
#    'peopleNmEn': 'LEE Dong-ha',
#    'staffRoleNm': '제작'},
#   {'peopleNm': '김연호', 'peopleNmEn': 'KIM Yeon-ho', 'staffRoleNm': '프로듀서'},
#   {'peopleNm': '연상호', 'peopleNmEn': 'YEON Sang-ho', 'staffRoleNm': '시나리오(각본)'},
#   {'peopleNm': '류용재',
#    'peopleNmEn': 'RYU Yong-jae',
#    'staffRoleNm': '시나리오(각본)'}]}

# %%
print(movieInfo['movieCd'],
      movieInfo['movieNm'],
      movieInfo['showTm'],
      len(movieInfo['actors']),
      len(movieInfo['showTypes']))
# Out:
# 20193450 반도 115 8 5

# %%
# 필요한 영화 코드
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
df
# Out:
#      rnum  rank  rankInten rankOldAndNew   movieCd          movieNm  \
# 0       1     1          0           OLD  20193450               반도
# 1       2     2          0           OLD  20193069            #살아있다
# 2       3     3          0           OLD  20204644  밤쉘: 세상을 바꾼 폭탄선언
# 3       4     4          1           OLD  20200162          소년시절의 너
# 4       5     5          1           OLD  20200845             비바리움
# ..    ...   ...        ...           ...       ...              ...
# 295     6     6          0           OLD  20196702             야구소녀
# 296     7     7          0           OLD  20205481            에어로너츠
# 297     8     8          0           OLD  20209463     나의 첫 번째 슈퍼스타
# 298     9     9          1           OLD  20184842      아이 캔 온리 이매진
# 299    10    10         -1           OLD  20198890   아이즈 온 미 : 더 무비
#
#          openDt    salesAmt  salesShare  salesInten  salesChange     salesAcc  \
# 0    2020-07-15  1183766780        87.7 -2804113320        -70.3  17065939380
# 1    2020-06-24    34586820         2.6   -37027380        -51.7  15675513340
# 2    2020-07-08    33282220         2.5   -35391720        -51.5   1218120740
# 3    2020-07-09    16606000         1.2    -8469800        -33.8    286011800
# 4    2020-07-16    10276380         0.8   -10257580        -50.0     80788380
# ..          ...         ...         ...         ...          ...          ...
# 295  2020-06-18    38904340         2.4      518120          1.3    149397880
# 296  2020-06-10    31135740         1.9    -6137600        -16.5    636643960
# 297  2020-06-10    21903740         1.3    -2283180         -9.4    430842560
# 298  2018-06-21     9095480         0.6     1405420         18.3    228396040
# 299  2020-06-10    16204500         1.0    -1128500         -6.5    487027000
#
#      audiCnt  audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0     141480    -301684       -68.1  1945520     2258    10778  20200720
# 1       4806      -4384       -47.7  1855485      477     1057  20200720
# 2       4085      -3599       -46.8   143174      459      953  20200720
# 3       2021       -808       -28.6    33373      162      303  20200720
# 4       1250      -1006       -44.6     9320      124      209  20200720
# ..       ...        ...         ...      ...      ...      ...       ...
# 295     4310        102         2.4    17096      254      401  20200621
# 296     3262       -613       -15.8    71614      256      352  20200621
# 297     2304       -211        -8.4    47185      182      238  20200621
# 298     1385        221        19.0    28932      131      150  20200621
# 299     1247        -88        -6.6    37743       96      106  20200621
#
# [300 rows x 19 columns]

# %%
codeitem = pd.unique(df['movieCd'])
codeitem.tolist()
print(codeitem)   

cine=[]
for code in codeitem:
    movieInfo = cineInfo(code)
    item={'movieCd':movieInfo['movieCd'],'movieNm':movieInfo['movieNm'],'showTm':movieInfo['showTm'],'actors':len(movieInfo['actors']),'showTypes':len(movieInfo['showTypes'])}
    cine.append(item)
    
dataframe=pd.DataFrame(cine)
dataframe.to_csv("cine.csv",index = False)
# Out:
# [20193450 20193069 20204644 20200162 20200845 20191048 20209882 20183813
#  20112561 20201841 20188364 19888010 20209961 20208983 20201421 20200749
#  20112703 20196201 20193263 20208182 20179462 20081056 20208617 20200802
#  20200836 20200361 20200083 20196702 20200846 20050112 20193859 20209644
#  20197863 20178522 20090161 20208828 20198890 20205481 20209463 20195483
#  20184842]

# %%
def graph_m(title):
    df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
    print(df.head())
    print('-'*60)
    #df=df.drop('Unnamed: 0',axis=1)  # 불러온 컬럼중 제거할 컬럼이 있다면 제거한다.
    df.drop('rnum',axis=1,inplace=True)
    print(df.head())
    print(df.columns)
    temp = df[df['movieNm'] == title]
    print(temp[['salesAmt','targetDt','movieNm']])
    print(temp.dtypes)
    mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
    plt.bar(temp['targetDt'].astype(str),temp['salesAmt']) 
    plt.title('일별 매출액 막대 그래프')
    plt.xlabel('날짜')
    plt.ylabel('총매출액')
    plt.xticks(fontsize=10, rotation=90)
    url1="" + title + ".png"
    plt.savefig(url1)

# %%
graph_m("반도")
# Out:
#    rnum  rank  rankInten rankOldAndNew   movieCd          movieNm      openDt  \
# 0     1     1          0           OLD  20193450               반도  2020-07-15
# 1     2     2          0           OLD  20193069            #살아있다  2020-06-24
# 2     3     3          0           OLD  20204644  밤쉘: 세상을 바꾼 폭탄선언  2020-07-08
# 3     4     4          1           OLD  20200162          소년시절의 너  2020-07-09
# 4     5     5          1           OLD  20200845             비바리움  2020-07-16
#
#      salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0  1183766780        87.7 -2804113320        -70.3  17065939380   141480
# 1    34586820         2.6   -37027380        -51.7  15675513340     4806
# 2    33282220         2.5   -35391720        -51.5   1218120740     4085
# 3    16606000         1.2    -8469800        -33.8    286011800     2021
# 4    10276380         0.8   -10257580        -50.0     80788380     1250
#
#    audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0    -301684       -68.1  1945520     2258    10778  20200720
# 1      -4384       -47.7  1855485      477     1057  20200720
# 2      -3599       -46.8   143174      459      953  20200720
# 3       -808       -28.6    33373      162      303  20200720
# 4      -1006       -44.6     9320      124      209  20200720
# ------------------------------------------------------------
#    rank  rankInten rankOldAndNew   movieCd          movieNm      openDt  \
# 0     1          0           OLD  20193450               반도  2020-07-15
# 1     2          0           OLD  20193069            #살아있다  2020-06-24
# 2     3          0           OLD  20204644  밤쉘: 세상을 바꾼 폭탄선언  2020-07-08
# 3     4          1           OLD  20200162          소년시절의 너  2020-07-09
# 4     5          1           OLD  20200845             비바리움  2020-07-16
#
#      salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0  1183766780        87.7 -2804113320        -70.3  17065939380   141480
# 1    34586820         2.6   -37027380        -51.7  15675513340     4806
# 2    33282220         2.5   -35391720        -51.5   1218120740     4085
# 3    16606000         1.2    -8469800        -33.8    286011800     2021
# 4    10276380         0.8   -10257580        -50.0     80788380     1250
#
#    audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0    -301684       -68.1  1945520     2258    10778  20200720
# 1      -4384       -47.7  1855485      477     1057  20200720
# 2      -3599       -46.8   143174      459      953  20200720
# 3       -808       -28.6    33373      162      303  20200720
# 4      -1006       -44.6     9320      124      209  20200720
# 반도
# Index(['rank', 'rankInten', 'rankOldAndNew', 'movieCd', 'movieNm', 'openDt',
#        'salesAmt', 'salesShare', 'salesInten', 'salesChange', 'salesAcc',
#        'audiCnt', 'audiInten', 'audiChange', 'audiAcc', 'scrnCnt', 'showCnt',
#        'targetDt'],
#       dtype='object')
#        salesAmt  targetDt movieNm
# 0    1183766780  20200720      반도
# 10   3987880100  20200719      반도
# 20   4663474260  20200718      반도
# 30   2412769960  20200717      반도
# 40   1870364540  20200716      반도
# 50   2931903740  20200715      반도
# 118    11990000  20200709      반도
# rank               int64
# rankInten          int64
# rankOldAndNew     object
# movieCd            int64
# movieNm           object
# openDt            object
# salesAmt           int64
# salesShare       float64
# salesInten         int64
# salesChange      float64
# salesAcc           int64
# audiCnt            int64
# audiInten          int64
# audiChange       float64
# audiAcc            int64
# scrnCnt            int64
# showCnt            int64
# targetDt           int64
# dtype: object

# %%
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
df.head()
# Out:
#    rnum  rank  rankInten rankOldAndNew   movieCd          movieNm      openDt  \
# 0     1     1          0           OLD  20193450               반도  2020-07-15
# 1     2     2          0           OLD  20193069            #살아있다  2020-06-24
# 2     3     3          0           OLD  20204644  밤쉘: 세상을 바꾼 폭탄선언  2020-07-08
# 3     4     4          1           OLD  20200162          소년시절의 너  2020-07-09
# 4     5     5          1           OLD  20200845             비바리움  2020-07-16
#
#      salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0  1183766780        87.7 -2804113320        -70.3  17065939380   141480
# 1    34586820         2.6   -37027380        -51.7  15675513340     4806
# 2    33282220         2.5   -35391720        -51.5   1218120740     4085
# 3    16606000         1.2    -8469800        -33.8    286011800     2021
# 4    10276380         0.8   -10257580        -50.0     80788380     1250
#
#    audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0    -301684       -68.1  1945520     2258    10778  20200720
# 1      -4384       -47.7  1855485      477     1057  20200720
# 2      -3599       -46.8   143174      459      953  20200720
# 3       -808       -28.6    33373      162      303  20200720
# 4      -1006       -44.6     9320      124      209  20200720

# %%
df['movieNm'] == '반도'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Name: movieNm, Length: 300, dtype: bool

# %%
temp1 = df[df['movieNm'] == '반도']
temp1.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 0      1     1          0           OLD  20193450      반도  2020-07-15
# 10     1     1          0           OLD  20193450      반도  2020-07-15
# 20     1     1          0           OLD  20193450      반도  2020-07-15
# 30     1     1          0           OLD  20193450      반도  2020-07-15
# 40     1     1          0           OLD  20193450      반도  2020-07-15
#
#       salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0   1183766780        87.7 -2804113320        -70.3  17065939380   141480
# 10  3987880100        92.5  -675594160        -14.5  15882172600   443164
# 20  4663474260        93.7  2250704300         93.3  11894292500   516546
# 30  2412769960        93.3   542405420         29.0   7230818240   265813
# 40  1870364540        91.6 -1061539200        -36.2   4818048280   223743
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0     -301684       -68.1  1945520     2258    10778  20200720
# 10     -73382       -14.2  1804040     2541    13353  20200719
# 20     250733        94.3  1360876     2575    13769  20200718
# 30      42070        18.8   844330     2457    12598  20200717
# 40    -129267       -36.6   578517     2358    11846  20200716

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
plt.plot([str(x) for x in temp1['targetDt']], temp1['salesAmt'])
plt.title('"{}"의 일별 매출액(salesAmt) 선 그래프'.format(temp1.iloc[0,5]))
plt.xlabel('날짜')
plt.ylabel('매출액')
plt.xticks(fontsize=9, rotation=90)
plt.show()

# %%
temp1.iloc[0,5]
# Out:
# '반도'

# %%
temp = df.groupby('movieNm').sum()
temp
# Out:
#                          rnum  rank  rankInten    movieCd     salesAmt  \
# movieNm
# #살아있다                      41    41          6  565405932  15662346340
# BIFAN2020 판타스틱 단편 걸작선 1    45    45          9  141409947    113400000
# 결백                        107   107         -7  605514390   3103824500
# 그레텔과 헨젤                    33    33         -4   80832728     69832560
# 나의 첫 번째 슈퍼스타               16    16          0   40418926     27310460
# 너와 파도를 탈 수 있다면             39    39          1   80773052     40839580
# 다크 나이트                     30    30          0  140567392    364168980
# 다크 나이트 라이즈                 31    31         -1  140788921    232635620
# 맛있는 녀석들                    14    14         18   40376728     21967080
# 반도                         15    15         10  141354150  17062149380
# 밤쉘: 세상을 바꾼 폭탄선언            44    44         -1  282865016   1205747340
# 배트맨 비긴즈                    29    29          1  140350784    241625160
# 부산행:익스텐디드                  18    18          1   40401692     12211000
# 부활                         29    29          3   60605523     15170000
# 불량한 가족                     10    10          0   20208828      5445000
# 블루 아워                       7     7          0   20209882      9738000
# 비바리움                       28    28         77  101004225     71527880
# 사라진 시간                     44    44         -2  201938590    674598520
# 소년시절의 너                    59    59         -1  242401944    271827800
# 소리꾼                        80    80          0  302943015    623098260
# 슬럼독 밀리어네어                  30    30          1   60270483     26112000
# 시네마 천국                     10     9          8   19888010      4860500
# 시라이                        20    20          2   40417966      7851460
# 아무튼, 아담                    49    49         -3  121202166     48399500
# 아이 캔 온리 이매진                 9     9          1   20184842      9095480
# 아이즈 온 미 : 더 무비             28    28          0   60596670     35451500
# 야구소녀                      112   112         -3  282753828    171067960
# 에어로너츠                      24    24         -3   60616443     44988800
# 에이브의 쿠킹 다이어리               10    10          0   20195483      3605000
# 엔딩스 비기닝스                   50    50         -1  141467508     99909960
# 온워드: 단 하루의 기적             130   130         -4  605731440   2379921480
# 원 데이                      110   110         10  261463293    147518100
# 위대한 쇼맨                    122   122         -5  363230316    244234380
# 인베이젼 2020                  42    42          5  141460319    167223060
# 지저귀는 새는 날지 않는다             14    14          0   40419922     15384400
# 침입자                        65    65         -1  181780767    198198600
# 콜 미 바이 유어 네임               28    28          7   60535566     18870180
# 킬 스위치                       7     7         83   20200802      5010000
# 트로이 디렉터스 컷                 43    43          0  101004180     44154280
# 파리의 인어                      9     9          0   20200749      3787000
# 해피 디 데이                    19    19          1   40400166      8178520
#
#                          salesShare  salesInten  salesChange      salesAcc  \
# movieNm
# #살아있다                        1174.0    34586820      52417.1  322540302900
# BIFAN2020 판타스틱 단편 걸작선 1        11.3    17400000        279.7     455400000
# 결백                            294.9  -535654700         28.9  204145023400
# 그레텔과 헨젤                        10.5    22450140        132.3     217926800
# 나의 첫 번째 슈퍼스타                    2.7   -18780200        -84.7     867091840
# 너와 파도를 탈 수 있다면                  6.8    -1257900         55.6     222512120
# 다크 나이트                         43.9    34007920         99.4  196048670220
# 다크 나이트 라이즈                     36.0    18218920         68.2  334766163460
# 맛있는 녀석들                         0.5    11974760       1005.1      34074400
# 반도                            555.9  1193156780        462.5   59854734740
# 밤쉘: 세상을 바꾼 폭탄선언               142.1    44000220        221.3   10462763900
# 배트맨 비긴즈                        13.1    22660460        217.6   39830158840
# 부산행:익스텐디드                       1.2     8581000        173.7      25309000
# 부활                              1.1     3485000        102.2     116143500
# 불량한 가족                          0.4     5445000        100.0       5445000
# 블루 아워                           0.7     9738000        100.0      11310400
# 비바리움                            2.6    10183380      11615.6     252596480
# 사라진 시간                         66.2  -399051860       -131.3   15011637800
# 소년시절의 너                        30.4    16606000        119.8    2199200200
# 소리꾼                            78.4    26627520        499.1    6299828580
# 슬럼독 밀리어네어                       0.9     5038000         67.1   22246305400
# 시네마 천국                          0.1     3903500        407.9     306935200
# 시라이                             0.2     4812460        114.5      15261520
# 아무튼, 아담                         6.2     4639500         40.1     199971500
# 아이 캔 온리 이매진                     0.6     1405420         18.3     228396040
# 아이즈 온 미 : 더 무비                  5.9    -4164000         47.7    1486406000
# 야구소녀                           14.7   -33516040         31.9    3112588440
# 에어로너츠                           5.5   -29898740        -81.9    1930263400
# 에이브의 쿠킹 다이어리                    0.9     3605000        100.0       8868000
# 엔딩스 비기닝스                        5.8     8439200        114.1     436403320
# 온워드: 단 하루의 기적                 193.7  -459388200        534.1   81333040660
# 원 데이                           17.4     3353900        514.8   20877438600
# 위대한 쇼맨                         20.3   -32909440        259.7  238122239120
# 인베이젼 2020                      18.8     3937960        533.2     779832000
# 지저귀는 새는 날지 않는다                  0.7     6943420         82.3      29925380
# 침입자                            21.2   -94759000       -117.0   42758186720
# 콜 미 바이 유어 네임                    1.6     3713280        523.0    5647226944
# 킬 스위치                           1.1     4958000       9534.6       5184900
# 트로이 디렉터스 컷                      5.4     6868680        150.9     139218560
# 파리의 인어                          0.1     3787000        100.0       3787000
# 해피 디 데이                         1.3     2040780         39.2      40032740
#
#                          audiCnt  audiInten  audiChange   audiAcc  scrnCnt  \
# movieNm
# #살아있다                    1852718       4806     16445.4  38433614    32250
# BIFAN2020 판타스틱 단편 걸작선 1    18900       2900       279.7     75900       37
# 결백                        363352     -57504       -20.3  23029128    14653
# 그레텔과 헨젤                     7998       2463       123.3     24261     1232
# 나의 첫 번째 슈퍼스타                2965      -1854       -79.7     95031      324
# 너와 파도를 탈 수 있다면              4806        125        59.8     25457      876
# 다크 나이트                     46289       4288        98.3  29422002     2502
# 다크 나이트 라이즈                 28831       2318        72.8  44922424     2070
# 맛있는 녀석들                     2694       1455       965.0      4223      297
# 반도                       1945150     142674       691.2   6889821    14536
# 밤쉘: 세상을 바꾼 폭탄선언           141766       5295       194.4   1240940     8241
# 배트맨 비긴즈                    33051       2820       233.2   6217760     1964
# 부산행:익스텐디드                   1539       1080       173.0      3186      174
# 부활                          1888        406       107.2     14760      143
# 불량한 가족                       605        605       100.0       605        3
# 블루 아워                       1082       1082       100.0      1242        1
# 비바리움                        8193       1238     10578.6     29285      631
# 사라진 시간                     77702     -42333      -148.3   1673804     5249
# 소년시절의 너                    31207       2021       113.0    258154     2159
# 소리꾼                        76559       3176       479.5    774541     5764
# 슬럼독 밀리어네어                   4360        833        66.5   3349181      138
# 시네마 천국                       813        654       411.3     49867       20
# 시라이                          922        551       106.7      1819      132
# 아무튼, 아담                     6695        685        32.8     27760      600
# 아이 캔 온리 이매진                 1385        221        19.0     28932      131
# 아이즈 온 미 : 더 무비              2732       -319        47.6    115183      272
# 야구소녀                       19699      -3797       -45.5    360605     1594
# 에어로너츠                       4989      -2943       -74.2    217364      652
# 에이브의 쿠킹 다이어리                 457        457       100.0      1120        3
# 엔딩스 비기닝스                   12204       1077        83.6     54166     1628
# 온워드: 단 하루의 기적             281109     -49906       514.2   9357171    13188
# 원 데이                       17308        434       559.9   2824179     1539
# 위대한 쇼맨                     40298      -5403       239.5  30241085     2197
# 인베이젼 2020                  20192        569       632.4     95167     2257
# 지저귀는 새는 날지 않는다              1718        739        75.5      3337      162
# 침입자                        23080     -10320      -110.1   4722666     2223
# 콜 미 바이 유어 네임                2324        469       336.6    670220      125
# 킬 스위치                       1001        995     16583.3      1021       51
# 트로이 디렉터스 컷                  5173        853       152.1     16025      720
# 파리의 인어                       541        541       100.0       541        4
# 해피 디 데이                     1030        329        43.1      4887      247
#
#                          showCnt   targetDt
# movieNm
# #살아있다                     131016  565619222
# BIFAN2020 판타스틱 단편 걸작선 1      167  141404991
# 결백                         37991  606020465
# 그레텔과 헨젤                     1953   80802838
# 나의 첫 번째 슈퍼스타                 423   40401243
# 너와 파도를 탈 수 있다면              1114   80802847
# 다크 나이트                      4065  141404928
# 다크 나이트 라이즈                  3434  141404977
# 맛있는 녀석들                      347   40401437
# 반도                         74176  141405014
# 밤쉘: 세상을 바꾼 폭탄선언            22538  282809907
# 배트맨 비긴즈                     3434  141404389
# 부산행:익스텐디드                    338   40401405
# 부활                           155   60602141
# 불량한 가족                         4   20200624
# 블루 아워                          4   20200720
# 비바리움                        1024  101003590
# 사라진 시간                     12039  202006255
# 소년시절의 너                     4189  242408574
# 소리꾼                        13385  303010528
# 슬럼독 밀리어네어                    189   60601881
# 시네마 천국                        22   20200718
# 시라이                          173   40401432
# 아무튼, 아담                      926  121204227
# 아이 캔 온리 이매진                  150   20200621
# 아이즈 온 미 : 더 무비               299   60601866
# 야구소녀                        2474  282809066
# 에어로너츠                        887   60601866
# 에이브의 쿠킹 다이어리                   3   20200622
# 엔딩스 비기닝스                    2236  141404389
# 온워드: 단 하루의 기적              29785  606020465
# 원 데이                        2745  262609282
# 위대한 쇼맨                      3053  363611891
# 인베이젼 2020                   3569  141404928
# 지저귀는 새는 날지 않는다               208   40401433
# 침입자                         3728  181805630
# 콜 미 바이 유어 네임                 161   60601884
# 킬 스위치                         51   20200707
# 트로이 디렉터스 컷                   770  101003525
# 파리의 인어                         4   20200715
# 해피 디 데이                      297   40401407

# %%
temp = df.groupby('movieNm').count()
temp
# Out:
#                          rnum  rank  rankInten  rankOldAndNew  movieCd  \
# movieNm
# #살아있다                      28    28         28             28       28
# BIFAN2020 판타스틱 단편 걸작선 1     7     7          7              7        7
# 결백                         30    30         30             30       30
# 그레텔과 헨젤                     4     4          4              4        4
# 나의 첫 번째 슈퍼스타                2     2          2              2        2
# 너와 파도를 탈 수 있다면              4     4          4              4        4
# 다크 나이트                      7     7          7              7        7
# 다크 나이트 라이즈                  7     7          7              7        7
# 맛있는 녀석들                     2     2          2              2        2
# 반도                          7     7          7              7        7
# 밤쉘: 세상을 바꾼 폭탄선언            14    14         14             14       14
# 배트맨 비긴즈                     7     7          7              7        7
# 부산행:익스텐디드                   2     2          2              2        2
# 부활                          3     3          3              3        3
# 불량한 가족                      1     1          1              1        1
# 블루 아워                       1     1          1              1        1
# 비바리움                        5     5          5              5        5
# 사라진 시간                     10    10         10             10       10
# 소년시절의 너                    12    12         12             12       12
# 소리꾼                        15    15         15             15       15
# 슬럼독 밀리어네어                   3     3          3              3        3
# 시네마 천국                      1     1          1              1        1
# 시라이                         2     2          2              2        2
# 아무튼, 아담                     6     6          6              6        6
# 아이 캔 온리 이매진                 1     1          1              1        1
# 아이즈 온 미 : 더 무비              3     3          3              3        3
# 야구소녀                       14    14         14             14       14
# 에어로너츠                       3     3          3              3        3
# 에이브의 쿠킹 다이어리                1     1          1              1        1
# 엔딩스 비기닝스                    7     7          7              7        7
# 온워드: 단 하루의 기적              30    30         30             30       30
# 원 데이                       13    13         13             13       13
# 위대한 쇼맨                     18    18         18             18       18
# 인베이젼 2020                   7     7          7              7        7
# 지저귀는 새는 날지 않는다              2     2          2              2        2
# 침입자                         9     9          9              9        9
# 콜 미 바이 유어 네임                3     3          3              3        3
# 킬 스위치                       1     1          1              1        1
# 트로이 디렉터스 컷                  5     5          5              5        5
# 파리의 인어                      1     1          1              1        1
# 해피 디 데이                     2     2          2              2        2
#
#                          openDt  salesAmt  salesShare  salesInten  \
# movieNm
# #살아있다                        28        28          28          28
# BIFAN2020 판타스틱 단편 걸작선 1       7         7           7           7
# 결백                           30        30          30          30
# 그레텔과 헨젤                       4         4           4           4
# 나의 첫 번째 슈퍼스타                  2         2           2           2
# 너와 파도를 탈 수 있다면                4         4           4           4
# 다크 나이트                        7         7           7           7
# 다크 나이트 라이즈                    7         7           7           7
# 맛있는 녀석들                       2         2           2           2
# 반도                            7         7           7           7
# 밤쉘: 세상을 바꾼 폭탄선언              14        14          14          14
# 배트맨 비긴즈                       7         7           7           7
# 부산행:익스텐디드                     2         2           2           2
# 부활                            3         3           3           3
# 불량한 가족                        1         1           1           1
# 블루 아워                         1         1           1           1
# 비바리움                          5         5           5           5
# 사라진 시간                       10        10          10          10
# 소년시절의 너                      12        12          12          12
# 소리꾼                          15        15          15          15
# 슬럼독 밀리어네어                     3         3           3           3
# 시네마 천국                        1         1           1           1
# 시라이                           2         2           2           2
# 아무튼, 아담                       6         6           6           6
# 아이 캔 온리 이매진                   1         1           1           1
# 아이즈 온 미 : 더 무비                3         3           3           3
# 야구소녀                         14        14          14          14
# 에어로너츠                         3         3           3           3
# 에이브의 쿠킹 다이어리                  1         1           1           1
# 엔딩스 비기닝스                      7         7           7           7
# 온워드: 단 하루의 기적                30        30          30          30
# 원 데이                         13        13          13          13
# 위대한 쇼맨                       18        18          18          18
# 인베이젼 2020                     7         7           7           7
# 지저귀는 새는 날지 않는다                2         2           2           2
# 침입자                           9         9           9           9
# 콜 미 바이 유어 네임                  3         3           3           3
# 킬 스위치                         1         1           1           1
# 트로이 디렉터스 컷                    5         5           5           5
# 파리의 인어                        1         1           1           1
# 해피 디 데이                       2         2           2           2
#
#                          salesChange  salesAcc  audiCnt  audiInten  \
# movieNm
# #살아있다                             28        28       28         28
# BIFAN2020 판타스틱 단편 걸작선 1            7         7        7          7
# 결백                                30        30       30         30
# 그레텔과 헨젤                            4         4        4          4
# 나의 첫 번째 슈퍼스타                       2         2        2          2
# 너와 파도를 탈 수 있다면                     4         4        4          4
# 다크 나이트                             7         7        7          7
# 다크 나이트 라이즈                         7         7        7          7
# 맛있는 녀석들                            2         2        2          2
# 반도                                 7         7        7          7
# 밤쉘: 세상을 바꾼 폭탄선언                   14        14       14         14
# 배트맨 비긴즈                            7         7        7          7
# 부산행:익스텐디드                          2         2        2          2
# 부활                                 3         3        3          3
# 불량한 가족                             1         1        1          1
# 블루 아워                              1         1        1          1
# 비바리움                               5         5        5          5
# 사라진 시간                            10        10       10         10
# 소년시절의 너                           12        12       12         12
# 소리꾼                               15        15       15         15
# 슬럼독 밀리어네어                          3         3        3          3
# 시네마 천국                             1         1        1          1
# 시라이                                2         2        2          2
# 아무튼, 아담                            6         6        6          6
# 아이 캔 온리 이매진                        1         1        1          1
# 아이즈 온 미 : 더 무비                     3         3        3          3
# 야구소녀                              14        14       14         14
# 에어로너츠                              3         3        3          3
# 에이브의 쿠킹 다이어리                       1         1        1          1
# 엔딩스 비기닝스                           7         7        7          7
# 온워드: 단 하루의 기적                     30        30       30         30
# 원 데이                              13        13       13         13
# 위대한 쇼맨                            18        18       18         18
# 인베이젼 2020                          7         7        7          7
# 지저귀는 새는 날지 않는다                     2         2        2          2
# 침입자                                9         9        9          9
# 콜 미 바이 유어 네임                       3         3        3          3
# 킬 스위치                              1         1        1          1
# 트로이 디렉터스 컷                         5         5        5          5
# 파리의 인어                             1         1        1          1
# 해피 디 데이                            2         2        2          2
#
#                          audiChange  audiAcc  scrnCnt  showCnt  targetDt
# movieNm
# #살아있다                            28       28       28       28        28
# BIFAN2020 판타스틱 단편 걸작선 1           7        7        7        7         7
# 결백                               30       30       30       30        30
# 그레텔과 헨젤                           4        4        4        4         4
# 나의 첫 번째 슈퍼스타                      2        2        2        2         2
# 너와 파도를 탈 수 있다면                    4        4        4        4         4
# 다크 나이트                            7        7        7        7         7
# 다크 나이트 라이즈                        7        7        7        7         7
# 맛있는 녀석들                           2        2        2        2         2
# 반도                                7        7        7        7         7
# 밤쉘: 세상을 바꾼 폭탄선언                  14       14       14       14        14
# 배트맨 비긴즈                           7        7        7        7         7
# 부산행:익스텐디드                         2        2        2        2         2
# 부활                                3        3        3        3         3
# 불량한 가족                            1        1        1        1         1
# 블루 아워                             1        1        1        1         1
# 비바리움                              5        5        5        5         5
# 사라진 시간                           10       10       10       10        10
# 소년시절의 너                          12       12       12       12        12
# 소리꾼                              15       15       15       15        15
# 슬럼독 밀리어네어                         3        3        3        3         3
# 시네마 천국                            1        1        1        1         1
# 시라이                               2        2        2        2         2
# 아무튼, 아담                           6        6        6        6         6
# 아이 캔 온리 이매진                       1        1        1        1         1
# 아이즈 온 미 : 더 무비                    3        3        3        3         3
# 야구소녀                             14       14       14       14        14
# 에어로너츠                             3        3        3        3         3
# 에이브의 쿠킹 다이어리                      1        1        1        1         1
# 엔딩스 비기닝스                          7        7        7        7         7
# 온워드: 단 하루의 기적                    30       30       30       30        30
# 원 데이                             13       13       13       13        13
# 위대한 쇼맨                           18       18       18       18        18
# 인베이젼 2020                         7        7        7        7         7
# 지저귀는 새는 날지 않는다                    2        2        2        2         2
# 침입자                               9        9        9        9         9
# 콜 미 바이 유어 네임                      3        3        3        3         3
# 킬 스위치                             1        1        1        1         1
# 트로이 디렉터스 컷                        5        5        5        5         5
# 파리의 인어                            1        1        1        1         1
# 해피 디 데이                           2        2        2        2         2

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
plt.figure(figsize=(15, 5))
plt.bar(temp.index, temp['salesAmt']) 
plt.title('영화명(movieNm)별 총 매출액 막대 그래프')
plt.xlabel('영화명')
plt.ylabel('총매출액')
plt.xticks(fontsize=9, rotation=90)
plt.show()

# %% [markdown]
# - 분포도 그리기

# %%
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
temp = df.groupby('movieNm').sum()
temp.head()
# Out:
#                          rnum  rank  rankInten    movieCd     salesAmt  \
# movieNm
# #살아있다                      41    41          6  565405932  15662346340
# BIFAN2020 판타스틱 단편 걸작선 1    45    45          9  141409947    113400000
# 결백                        107   107         -7  605514390   3103824500
# 그레텔과 헨젤                    33    33         -4   80832728     69832560
# 나의 첫 번째 슈퍼스타               16    16          0   40418926     27310460
#
#                          salesShare  salesInten  salesChange      salesAcc  \
# movieNm
# #살아있다                        1174.0    34586820      52417.1  322540302900
# BIFAN2020 판타스틱 단편 걸작선 1        11.3    17400000        279.7     455400000
# 결백                            294.9  -535654700         28.9  204145023400
# 그레텔과 헨젤                        10.5    22450140        132.3     217926800
# 나의 첫 번째 슈퍼스타                    2.7   -18780200        -84.7     867091840
#
#                          audiCnt  audiInten  audiChange   audiAcc  scrnCnt  \
# movieNm
# #살아있다                    1852718       4806     16445.4  38433614    32250
# BIFAN2020 판타스틱 단편 걸작선 1    18900       2900       279.7     75900       37
# 결백                        363352     -57504       -20.3  23029128    14653
# 그레텔과 헨젤                     7998       2463       123.3     24261     1232
# 나의 첫 번째 슈퍼스타                2965      -1854       -79.7     95031      324
#
#                          showCnt   targetDt
# movieNm
# #살아있다                     131016  565619222
# BIFAN2020 판타스틱 단편 걸작선 1      167  141404991
# 결백                         37991  606020465
# 그레텔과 헨젤                     1953   80802838
# 나의 첫 번째 슈퍼스타                 423   40401243

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
plt.figure(figsize=(10, 5))
# plt.scatter(temp['salesAmt'], temp['audiCnt']) 
plt.scatter(temp['salesAmt'], temp['audiCnt']) 
plt.title('총 매출액과 총 관객수 분포도')
plt.xlabel('총매출액')
plt.ylabel('총관객수')
plt.show()

# %% [markdown]
# - 파이차트 그리기

# %%
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
temp = df.groupby('movieNm').sum()
temp = temp.sort_values(by='salesAmt', ascending=0)
temp = temp.iloc[:10]
temp
# Out:
#                  rnum  rank  rankInten    movieCd     salesAmt  salesShare  \
# movieNm
# 반도                 15    15         10  141354150  17062149380       555.9
# #살아있다              41    41          6  565405932  15662346340      1174.0
# 결백                107   107         -7  605514390   3103824500       294.9
# 온워드: 단 하루의 기적     130   130         -4  605731440   2379921480       193.7
# 밤쉘: 세상을 바꾼 폭탄선언    44    44         -1  282865016   1205747340       142.1
# 사라진 시간             44    44         -2  201938590    674598520        66.2
# 소리꾼                80    80          0  302943015    623098260        78.4
# 다크 나이트             30    30          0  140567392    364168980        43.9
# 소년시절의 너            59    59         -1  242401944    271827800        30.4
# 위대한 쇼맨            122   122         -5  363230316    244234380        20.3
#
#                  salesInten  salesChange      salesAcc  audiCnt  audiInten  \
# movieNm
# 반도               1193156780        462.5   59854734740  1945150     142674
# #살아있다              34586820      52417.1  322540302900  1852718       4806
# 결백               -535654700         28.9  204145023400   363352     -57504
# 온워드: 단 하루의 기적    -459388200        534.1   81333040660   281109     -49906
# 밤쉘: 세상을 바꾼 폭탄선언    44000220        221.3   10462763900   141766       5295
# 사라진 시간           -399051860       -131.3   15011637800    77702     -42333
# 소리꾼                26627520        499.1    6299828580    76559       3176
# 다크 나이트             34007920         99.4  196048670220    46289       4288
# 소년시절의 너            16606000        119.8    2199200200    31207       2021
# 위대한 쇼맨            -32909440        259.7  238122239120    40298      -5403
#
#                  audiChange   audiAcc  scrnCnt  showCnt   targetDt
# movieNm
# 반도                    691.2   6889821    14536    74176  141405014
# #살아있다               16445.4  38433614    32250   131016  565619222
# 결백                    -20.3  23029128    14653    37991  606020465
# 온워드: 단 하루의 기적         514.2   9357171    13188    29785  606020465
# 밤쉘: 세상을 바꾼 폭탄선언       194.4   1240940     8241    22538  282809907
# 사라진 시간               -148.3   1673804     5249    12039  202006255
# 소리꾼                   479.5    774541     5764    13385  303010528
# 다크 나이트                 98.3  29422002     2502     4065  141404928
# 소년시절의 너               113.0    258154     2159     4189  242408574
# 위대한 쇼맨                239.5  30241085     2197     3053  363611891

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
mpl.rcParams['font.size'] = 9
plt.figure(figsize=(10, 5))
plt.pie(temp['salesAmt'], labels=temp.index, autopct='%.1f%%', shadow=True)
plt.title('총 매출액 TOP 10 의 영화명(movieNm) 파이 차트')
plt.show()

# %%
df1 = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
df1
# Out:
#      rnum  rank  rankInten rankOldAndNew   movieCd          movieNm  \
# 0       1     1          0           OLD  20193450               반도
# 1       2     2          0           OLD  20193069            #살아있다
# 2       3     3          0           OLD  20204644  밤쉘: 세상을 바꾼 폭탄선언
# 3       4     4          1           OLD  20200162          소년시절의 너
# 4       5     5          1           OLD  20200845             비바리움
# ..    ...   ...        ...           ...       ...              ...
# 295     6     6          0           OLD  20196702             야구소녀
# 296     7     7          0           OLD  20205481            에어로너츠
# 297     8     8          0           OLD  20209463     나의 첫 번째 슈퍼스타
# 298     9     9          1           OLD  20184842      아이 캔 온리 이매진
# 299    10    10         -1           OLD  20198890   아이즈 온 미 : 더 무비
#
#          openDt    salesAmt  salesShare  salesInten  salesChange     salesAcc  \
# 0    2020-07-15  1183766780        87.7 -2804113320        -70.3  17065939380
# 1    2020-06-24    34586820         2.6   -37027380        -51.7  15675513340
# 2    2020-07-08    33282220         2.5   -35391720        -51.5   1218120740
# 3    2020-07-09    16606000         1.2    -8469800        -33.8    286011800
# 4    2020-07-16    10276380         0.8   -10257580        -50.0     80788380
# ..          ...         ...         ...         ...          ...          ...
# 295  2020-06-18    38904340         2.4      518120          1.3    149397880
# 296  2020-06-10    31135740         1.9    -6137600        -16.5    636643960
# 297  2020-06-10    21903740         1.3    -2283180         -9.4    430842560
# 298  2018-06-21     9095480         0.6     1405420         18.3    228396040
# 299  2020-06-10    16204500         1.0    -1128500         -6.5    487027000
#
#      audiCnt  audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0     141480    -301684       -68.1  1945520     2258    10778  20200720
# 1       4806      -4384       -47.7  1855485      477     1057  20200720
# 2       4085      -3599       -46.8   143174      459      953  20200720
# 3       2021       -808       -28.6    33373      162      303  20200720
# 4       1250      -1006       -44.6     9320      124      209  20200720
# ..       ...        ...         ...      ...      ...      ...       ...
# 295     4310        102         2.4    17096      254      401  20200621
# 296     3262       -613       -15.8    71614      256      352  20200621
# 297     2304       -211        -8.4    47185      182      238  20200621
# 298     1385        221        19.0    28932      131      150  20200621
# 299     1247        -88        -6.6    37743       96      106  20200621
#
# [300 rows x 19 columns]

# %%
df2 = pd.read_csv(r'cine.csv',engine='python',encoding='utf-8')
df2
# Out:
#      movieCd                  movieNm  showTm  actors  showTypes
# 0   20193450                       반도     115       8          5
# 1   20193069                    #살아있다      97       2          3
# 2   20204644          밤쉘: 세상을 바꾼 폭탄선언     108       3          1
# 3   20200162                  소년시절의 너     135       1          1
# 4   20200845                     비바리움      97       2          1
# 5   20191048            온워드: 단 하루의 기적     102       4          5
# 6   20209882                    블루 아워      91       6          1
# 7   20183813                       결백     110      11          2
# 8   20112561                     원 데이     107       2          2
# 9   20201841                       부활     110       0          1
# 10  20188364                  맛있는 녀석들      98       0          2
# 11  19888010                   시네마 천국     124       5          3
# 12  20209961           지저귀는 새는 날지 않는다      85       2          1
# 13  20208983                      시라이      98       2          1
# 14  20201421  BIFAN2020 판타스틱 단편 걸작선 1      82       0          1
# 15  20200749                   파리의 인어     102       0          1
# 16  20112703               다크 나이트 라이즈     164       5          4
# 17  20196201                      소리꾼     118      15          1
# 18  20193263           너와 파도를 탈 수 있다면      95       4          1
# 19  20208182                  그레텔과 헨젤      87       2          1
# 20  20179462                   위대한 쇼맨     104       5          1
# 21  20081056                   다크 나이트     152       7          5
# 22  20208617                인베이젼 2020     130       2          1
# 23  20200802                    킬 스위치      91       2          1
# 24  20200836               트로이 디렉터스 컷     196       3          1
# 25  20200361                  아무튼, 아담     100       3          1
# 26  20200083                  해피 디 데이     113       4          1
# 27  20196702                     야구소녀     104       8          1
# 28  20200846                부산행:익스텐디드     120       9          3
# 29  20050112                  배트맨 비긴즈     134       3          4
# 30  20193859                   사라진 시간     104       7          1
# 31  20209644                 엔딩스 비기닝스     110       3          1
# 32  20197863                      침입자     102       7          2
# 33  20178522             콜 미 바이 유어 네임     131       5          1
# 34  20090161                슬럼독 밀리어네어     120       5          2
# 35  20208828                   불량한 가족     102       2          1
# 36  20198890           아이즈 온 미 : 더 무비     104      12          3
# 37  20205481                    에어로너츠     100       3          1
# 38  20209463             나의 첫 번째 슈퍼스타     113       2          1
# 39  20195483             에이브의 쿠킹 다이어리      86       2          1
# 40  20184842              아이 캔 온리 이매진     110       5          1

# %%
df3 = pd.merge(df1, df2, on='movieCd') 
df3
# Out:
#      rnum  rank  rankInten rankOldAndNew   movieCd     movieNm_x      openDt  \
# 0       1     1          0           OLD  20193450            반도  2020-07-15
# 1       1     1          0           OLD  20193450            반도  2020-07-15
# 2       1     1          0           OLD  20193450            반도  2020-07-15
# 3       1     1          0           OLD  20193450            반도  2020-07-15
# 4       1     1          0           OLD  20193450            반도  2020-07-15
# ..    ...   ...        ...           ...       ...           ...         ...
# 295     7     7          0           OLD  20205481         에어로너츠  2020-06-10
# 296     8     8          0           OLD  20209463  나의 첫 번째 슈퍼스타  2020-06-10
# 297     8     8          0           OLD  20209463  나의 첫 번째 슈퍼스타  2020-06-10
# 298    10    10          0           NEW  20195483  에이브의 쿠킹 다이어리  2020-06-24
# 299     9     9          1           OLD  20184842   아이 캔 온리 이매진  2018-06-21
#
#        salesAmt  salesShare  salesInten  ...  audiInten  audiChange  audiAcc  \
# 0    1183766780        87.7 -2804113320  ...    -301684       -68.1  1945520
# 1    3987880100        92.5  -675594160  ...     -73382       -14.2  1804040
# 2    4663474260        93.7  2250704300  ...     250733        94.3  1360876
# 3    2412769960        93.3   542405420  ...      42070        18.8   844330
# 4    1870364540        91.6 -1061539200  ...    -129267       -36.6   578517
# ..          ...         ...         ...  ...        ...         ...      ...
# 295    31135740         1.9    -6137600  ...       -613       -15.8    71614
# 296     5406720         1.4   -16497020  ...      -1643       -71.3    47846
# 297    21903740         1.3    -2283180  ...       -211        -8.4    47185
# 298     3605000         0.9     3605000  ...        457       100.0     1120
# 299     9095480         0.6     1405420  ...        221        19.0    28932
#
#      scrnCnt  showCnt  targetDt     movieNm_y  showTm  actors showTypes
# 0       2258    10778  20200720            반도     115       8         5
# 1       2541    13353  20200719            반도     115       8         5
# 2       2575    13769  20200718            반도     115       8         5
# 3       2457    12598  20200717            반도     115       8         5
# 4       2358    11846  20200716            반도     115       8         5
# ..       ...      ...       ...           ...     ...     ...       ...
# 295      256      352  20200621         에어로너츠     100       3         1
# 296      142      185  20200622  나의 첫 번째 슈퍼스타     113       2         1
# 297      182      238  20200621  나의 첫 번째 슈퍼스타     113       2         1
# 298        3        3  20200622  에이브의 쿠킹 다이어리      86       2         1
# 299      131      150  20200621   아이 캔 온리 이매진     110       5         1
#
# [300 rows x 23 columns]

# %%
df3['rankOldAndNew'].replace(['OLD','NEW'],[0,1], inplace=True)
# df3=df3['rankOldAndNew'].replace(['OLD','NEW'],[0,1])

# %%
df3
# Out:
#      rnum  rank  rankInten  rankOldAndNew   movieCd     movieNm_x      openDt  \
# 0       1     1          0              0  20193450            반도  2020-07-15
# 1       1     1          0              0  20193450            반도  2020-07-15
# 2       1     1          0              0  20193450            반도  2020-07-15
# 3       1     1          0              0  20193450            반도  2020-07-15
# 4       1     1          0              0  20193450            반도  2020-07-15
# ..    ...   ...        ...            ...       ...           ...         ...
# 295     7     7          0              0  20205481         에어로너츠  2020-06-10
# 296     8     8          0              0  20209463  나의 첫 번째 슈퍼스타  2020-06-10
# 297     8     8          0              0  20209463  나의 첫 번째 슈퍼스타  2020-06-10
# 298    10    10          0              1  20195483  에이브의 쿠킹 다이어리  2020-06-24
# 299     9     9          1              0  20184842   아이 캔 온리 이매진  2018-06-21
#
#        salesAmt  salesShare  salesInten  ...  audiInten  audiChange  audiAcc  \
# 0    1183766780        87.7 -2804113320  ...    -301684       -68.1  1945520
# 1    3987880100        92.5  -675594160  ...     -73382       -14.2  1804040
# 2    4663474260        93.7  2250704300  ...     250733        94.3  1360876
# 3    2412769960        93.3   542405420  ...      42070        18.8   844330
# 4    1870364540        91.6 -1061539200  ...    -129267       -36.6   578517
# ..          ...         ...         ...  ...        ...         ...      ...
# 295    31135740         1.9    -6137600  ...       -613       -15.8    71614
# 296     5406720         1.4   -16497020  ...      -1643       -71.3    47846
# 297    21903740         1.3    -2283180  ...       -211        -8.4    47185
# 298     3605000         0.9     3605000  ...        457       100.0     1120
# 299     9095480         0.6     1405420  ...        221        19.0    28932
#
#      scrnCnt  showCnt  targetDt     movieNm_y  showTm  actors showTypes
# 0       2258    10778  20200720            반도     115       8         5
# 1       2541    13353  20200719            반도     115       8         5
# 2       2575    13769  20200718            반도     115       8         5
# 3       2457    12598  20200717            반도     115       8         5
# 4       2358    11846  20200716            반도     115       8         5
# ..       ...      ...       ...           ...     ...     ...       ...
# 295      256      352  20200621         에어로너츠     100       3         1
# 296      142      185  20200622  나의 첫 번째 슈퍼스타     113       2         1
# 297      182      238  20200621  나의 첫 번째 슈퍼스타     113       2         1
# 298        3        3  20200622  에이브의 쿠킹 다이어리      86       2         1
# 299      131      150  20200621   아이 캔 온리 이매진     110       5         1
#
# [300 rows x 23 columns]

# %%
df3=df3.loc[:,['targetDt','rank','rankOldAndNew','movieCd','salesAmt','audiCnt','showTm','actors','showTypes']]
df3
# Out:
#      targetDt  rank  rankOldAndNew   movieCd    salesAmt  audiCnt  showTm  \
# 0    20200720     1              0  20193450  1183766780   141480     115
# 1    20200719     1              0  20193450  3987880100   443164     115
# 2    20200718     1              0  20193450  4663474260   516546     115
# 3    20200717     1              0  20193450  2412769960   265813     115
# 4    20200716     1              0  20193450  1870364540   223743     115
# ..        ...   ...            ...       ...         ...      ...     ...
# 295  20200621     7              0  20205481    31135740     3262     100
# 296  20200622     8              0  20209463     5406720      661     113
# 297  20200621     8              0  20209463    21903740     2304     113
# 298  20200622    10              1  20195483     3605000      457      86
# 299  20200621     9              0  20184842     9095480     1385     110
#
#      actors  showTypes
# 0         8          5
# 1         8          5
# 2         8          5
# 3         8          5
# 4         8          5
# ..      ...        ...
# 295       3          1
# 296       2          1
# 297       2          1
# 298       2          1
# 299       5          1
#
# [300 rows x 9 columns]

# %%
#상관계수 두 변수간의 연관된 정도를 나타낸다. 두변수가 동일하면 +1, 전혀 다르면 0, 반대방향으로 동일하면 -1
temp = df3.corr()
temp
# Out:
#                targetDt      rank  rankOldAndNew   movieCd  salesAmt  \
# targetDt       1.000000 -0.001032       0.026425  0.014357  0.004744
# rank          -0.001032  1.000000       0.129218 -0.038926 -0.394386
# rankOldAndNew  0.026425  0.129218       1.000000  0.036649  0.001695
# movieCd        0.014357 -0.038926       0.036649  1.000000  0.068833
# salesAmt       0.004744 -0.394386       0.001695  0.068833  1.000000
# audiCnt       -0.001198 -0.401823       0.005139  0.068389  0.997792
# showTm         0.107641  0.029273       0.047276 -0.381309 -0.052541
# actors        -0.140322 -0.074950      -0.096514  0.019033  0.029643
# showTypes      0.048948 -0.390665      -0.071681 -0.360990  0.306387
#
#                 audiCnt    showTm    actors  showTypes
# targetDt      -0.001198  0.107641 -0.140322   0.048948
# rank          -0.401823  0.029273 -0.074950  -0.390665
# rankOldAndNew  0.005139  0.047276 -0.096514  -0.071681
# movieCd        0.068389 -0.381309  0.019033  -0.360990
# salesAmt       0.997792 -0.052541  0.029643   0.306387
# audiCnt        1.000000 -0.055060  0.026896   0.309441
# showTm        -0.055060  1.000000  0.098731   0.100639
# actors         0.026896  0.098731  1.000000  -0.020079
# showTypes      0.309441  0.100639 -0.020079   1.000000

# %%
temp = temp.rename(index={'targetDt': '날짜','rank': '순위','rankOldAndNew': '신규진입여부','movieCd': '영화코드','salesAmt': '매출액','audiCnt': '관객수','showTm': '상영시간','actors': '배우 수','showTypes': '상영형태 수'})
temp = temp.rename(columns={'targetDt': '날짜','rank': '순위','rankOldAndNew': '신규진입여부','movieCd': '영화코드','salesAmt': '매출액','audiCnt': '관객수','showTm': '상영시간','actors': '배우 수','showTypes': '상영형태 수'})
temp
# Out:
#               날짜        순위    신규진입여부      영화코드       매출액       관객수      상영시간  \
# 날짜      1.000000 -0.001032  0.026425  0.014357  0.004744 -0.001198  0.107641
# 순위     -0.001032  1.000000  0.129218 -0.038926 -0.394386 -0.401823  0.029273
# 신규진입여부  0.026425  0.129218  1.000000  0.036649  0.001695  0.005139  0.047276
# 영화코드    0.014357 -0.038926  0.036649  1.000000  0.068833  0.068389 -0.381309
# 매출액     0.004744 -0.394386  0.001695  0.068833  1.000000  0.997792 -0.052541
# 관객수    -0.001198 -0.401823  0.005139  0.068389  0.997792  1.000000 -0.055060
# 상영시간    0.107641  0.029273  0.047276 -0.381309 -0.052541 -0.055060  1.000000
# 배우 수   -0.140322 -0.074950 -0.096514  0.019033  0.029643  0.026896  0.098731
# 상영형태 수  0.048948 -0.390665 -0.071681 -0.360990  0.306387  0.309441  0.100639
#
#             배우 수    상영형태 수
# 날짜     -0.140322  0.048948
# 순위     -0.074950 -0.390665
# 신규진입여부 -0.096514 -0.071681
# 영화코드    0.019033 -0.360990
# 매출액     0.029643  0.306387
# 관객수     0.026896  0.309441
# 상영시간    0.098731  0.100639
# 배우 수    1.000000 -0.020079
# 상영형태 수 -0.020079  1.000000

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
plt.figure(figsize=(10, 10))
plt.imshow(temp, cmap='hot')
plt.colorbar()
plt.title('영화 박스오피스의 컬럼들간의 상관계수 히트맵')
#plt.xticks(range(9), ['targetDt','rank','rankOldAndNew','movieCd','salesAmt','audiCnt','showTm','actors','showTypes'])
plt.xticks(range(len(temp.columns)), temp.columns)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(range(len(temp.index)), temp.index)
plt.yticks(fontsize=10, rotation=45)
plt.show()

# %%
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
df.head()
# Out:
#    rnum  rank  rankInten rankOldAndNew   movieCd          movieNm      openDt  \
# 0     1     1          0           OLD  20193450               반도  2020-07-15
# 1     2     2          0           OLD  20193069            #살아있다  2020-06-24
# 2     3     3          0           OLD  20204644  밤쉘: 세상을 바꾼 폭탄선언  2020-07-08
# 3     4     4          1           OLD  20200162          소년시절의 너  2020-07-09
# 4     5     5          1           OLD  20200845             비바리움  2020-07-16
#
#      salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0  1183766780        87.7 -2804113320        -70.3  17065939380   141480
# 1    34586820         2.6   -37027380        -51.7  15675513340     4806
# 2    33282220         2.5   -35391720        -51.5   1218120740     4085
# 3    16606000         1.2    -8469800        -33.8    286011800     2021
# 4    10276380         0.8   -10257580        -50.0     80788380     1250
#
#    audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0    -301684       -68.1  1945520     2258    10778  20200720
# 1      -4384       -47.7  1855485      477     1057  20200720
# 2      -3599       -46.8   143174      459      953  20200720
# 3       -808       -28.6    33373      162      303  20200720
# 4      -1006       -44.6     9320      124      209  20200720

# %%
temp1 = df[df['movieNm'] == '반도']
temp1.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 0      1     1          0           OLD  20193450      반도  2020-07-15
# 10     1     1          0           OLD  20193450      반도  2020-07-15
# 20     1     1          0           OLD  20193450      반도  2020-07-15
# 30     1     1          0           OLD  20193450      반도  2020-07-15
# 40     1     1          0           OLD  20193450      반도  2020-07-15
#
#       salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0   1183766780        87.7 -2804113320        -70.3  17065939380   141480
# 10  3987880100        92.5  -675594160        -14.5  15882172600   443164
# 20  4663474260        93.7  2250704300         93.3  11894292500   516546
# 30  2412769960        93.3   542405420         29.0   7230818240   265813
# 40  1870364540        91.6 -1061539200        -36.2   4818048280   223743
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0     -301684       -68.1  1945520     2258    10778  20200720
# 10     -73382       -14.2  1804040     2541    13353  20200719
# 20     250733        94.3  1360876     2575    13769  20200718
# 30      42070        18.8   844330     2457    12598  20200717
# 40    -129267       -36.6   578517     2358    11846  20200716

# %%
temp2 = df[df['movieNm'] == '#살아있다']
temp2.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 1      2     2          0           OLD  20193069   #살아있다  2020-06-24
# 11     2     2          0           OLD  20193069   #살아있다  2020-06-24
# 21     2     2          0           OLD  20193069   #살아있다  2020-06-24
# 31     2     2          0           OLD  20193069   #살아있다  2020-06-24
# 41     2     2          0           OLD  20193069   #살아있다  2020-06-24
#
#     salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 1   34586820         2.6   -37027380        -51.7  15675513340     4806
# 11  71614200         1.7     2041200          2.9  15640926520     9190
# 21  69573000         1.4    30031400         75.9  15569312320     8859
# 31  39541600         1.5     9917360         33.5  15499739320     5410
# 41  29624240         1.5    -2993960         -9.2  15460197720     4510
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 1       -4384       -47.7  1855485      477     1057  20200720
# 11        331         3.7  1850679      491     1093  20200719
# 21       3449        63.8  1841489      485     1079  20200718
# 31        900        20.0  1832630      480     1057  20200717
# 41       -317        -6.6  1827220      465      985  20200716

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
fig = plt.figure()
fig.set_size_inches(12,5)

#분할해 그리기 시작
axe = fig.add_subplot(1,2,1) #1행(row) 2열(column)중 첫 번째 subplot
axe.plot([str(x) for x in temp1['targetDt']], temp1['salesAmt'])
axe.set_title('인비저블맨')
axe.set_xlabel('날짜')
axe.set_ylabel('매출액')
for tick in axe.xaxis.get_major_ticks():
    tick.label.set_fontsize(9) 
    tick.label.set_rotation(90)
    
axe = fig.add_subplot(1,2,2) #1행(row) 2열(column)중 두번째 subplot
axe.plot([str(x) for x in temp2['targetDt']], temp2['salesAmt'])
axe.set_title('1917')
axe.set_xlabel('날짜')
axe.set_ylabel('매출액')
for tick in axe.xaxis.get_major_ticks():
    tick.label.set_fontsize(9) 
    tick.label.set_rotation(90)
plt.suptitle('영화명 "인비저블맨"의 일별 매출액(salesAmt)과 영화명 "1917"의 일별 매출액(salesAmt) 선 그래프')
#분할해 그리기 끝
plt.show()

# %%
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
df.head()
# Out:
#    rnum  rank  rankInten rankOldAndNew   movieCd          movieNm      openDt  \
# 0     1     1          0           OLD  20193450               반도  2020-07-15
# 1     2     2          0           OLD  20193069            #살아있다  2020-06-24
# 2     3     3          0           OLD  20204644  밤쉘: 세상을 바꾼 폭탄선언  2020-07-08
# 3     4     4          1           OLD  20200162          소년시절의 너  2020-07-09
# 4     5     5          1           OLD  20200845             비바리움  2020-07-16
#
#      salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0  1183766780        87.7 -2804113320        -70.3  17065939380   141480
# 1    34586820         2.6   -37027380        -51.7  15675513340     4806
# 2    33282220         2.5   -35391720        -51.5   1218120740     4085
# 3    16606000         1.2    -8469800        -33.8    286011800     2021
# 4    10276380         0.8   -10257580        -50.0     80788380     1250
#
#    audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0    -301684       -68.1  1945520     2258    10778  20200720
# 1      -4384       -47.7  1855485      477     1057  20200720
# 2      -3599       -46.8   143174      459      953  20200720
# 3       -808       -28.6    33373      162      303  20200720
# 4      -1006       -44.6     9320      124      209  20200720

# %%
temp1 = df[df['movieNm'] == '반도']
temp1.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 0      1     1          0           OLD  20193450      반도  2020-07-15
# 10     1     1          0           OLD  20193450      반도  2020-07-15
# 20     1     1          0           OLD  20193450      반도  2020-07-15
# 30     1     1          0           OLD  20193450      반도  2020-07-15
# 40     1     1          0           OLD  20193450      반도  2020-07-15
#
#       salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0   1183766780        87.7 -2804113320        -70.3  17065939380   141480
# 10  3987880100        92.5  -675594160        -14.5  15882172600   443164
# 20  4663474260        93.7  2250704300         93.3  11894292500   516546
# 30  2412769960        93.3   542405420         29.0   7230818240   265813
# 40  1870364540        91.6 -1061539200        -36.2   4818048280   223743
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0     -301684       -68.1  1945520     2258    10778  20200720
# 10     -73382       -14.2  1804040     2541    13353  20200719
# 20     250733        94.3  1360876     2575    13769  20200718
# 30      42070        18.8   844330     2457    12598  20200717
# 40    -129267       -36.6   578517     2358    11846  20200716

# %%
temp2 = df[df['movieNm'] == '#살아있다']
temp2.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 1      2     2          0           OLD  20193069   #살아있다  2020-06-24
# 11     2     2          0           OLD  20193069   #살아있다  2020-06-24
# 21     2     2          0           OLD  20193069   #살아있다  2020-06-24
# 31     2     2          0           OLD  20193069   #살아있다  2020-06-24
# 41     2     2          0           OLD  20193069   #살아있다  2020-06-24
#
#     salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 1   34586820         2.6   -37027380        -51.7  15675513340     4806
# 11  71614200         1.7     2041200          2.9  15640926520     9190
# 21  69573000         1.4    30031400         75.9  15569312320     8859
# 31  39541600         1.5     9917360         33.5  15499739320     5410
# 41  29624240         1.5    -2993960         -9.2  15460197720     4510
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 1       -4384       -47.7  1855485      477     1057  20200720
# 11        331         3.7  1850679      491     1093  20200719
# 21       3449        63.8  1841489      485     1079  20200718
# 31        900        20.0  1832630      480     1057  20200717
# 41       -317        -6.6  1827220      465      985  20200716

# %%
dates = list(set(temp1['targetDt']) | set(temp2['targetDt']))
dates.sort()
len(dates)
# Out:
# 28

# %%
def apply_temp1(date):
    return dates.index(date)
temp1['x'] = temp1['targetDt'].apply(apply_temp1)
temp1.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 0      1     1          0           OLD  20193450      반도  2020-07-15
# 10     1     1          0           OLD  20193450      반도  2020-07-15
# 20     1     1          0           OLD  20193450      반도  2020-07-15
# 30     1     1          0           OLD  20193450      반도  2020-07-15
# 40     1     1          0           OLD  20193450      반도  2020-07-15
#
#       salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0   1183766780        87.7 -2804113320        -70.3  17065939380   141480
# 10  3987880100        92.5  -675594160        -14.5  15882172600   443164
# 20  4663474260        93.7  2250704300         93.3  11894292500   516546
# 30  2412769960        93.3   542405420         29.0   7230818240   265813
# 40  1870364540        91.6 -1061539200        -36.2   4818048280   223743
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt   x
# 0     -301684       -68.1  1945520     2258    10778  20200720  27
# 10     -73382       -14.2  1804040     2541    13353  20200719  26
# 20     250733        94.3  1360876     2575    13769  20200718  25
# 30      42070        18.8   844330     2457    12598  20200717  24
# 40    -129267       -36.6   578517     2358    11846  20200716  23

# %%
def apply_temp2(date):
    return dates.index(date)
temp2['x'] = temp2['targetDt'].apply(apply_temp2)
temp2.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 1      2     2          0           OLD  20193069   #살아있다  2020-06-24
# 11     2     2          0           OLD  20193069   #살아있다  2020-06-24
# 21     2     2          0           OLD  20193069   #살아있다  2020-06-24
# 31     2     2          0           OLD  20193069   #살아있다  2020-06-24
# 41     2     2          0           OLD  20193069   #살아있다  2020-06-24
#
#     salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 1   34586820         2.6   -37027380        -51.7  15675513340     4806
# 11  71614200         1.7     2041200          2.9  15640926520     9190
# 21  69573000         1.4    30031400         75.9  15569312320     8859
# 31  39541600         1.5     9917360         33.5  15499739320     5410
# 41  29624240         1.5    -2993960         -9.2  15460197720     4510
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt   x
# 1       -4384       -47.7  1855485      477     1057  20200720  27
# 11        331         3.7  1850679      491     1093  20200719  26
# 21       3449        63.8  1841489      485     1079  20200718  25
# 31        900        20.0  1832630      480     1057  20200717  24
# 41       -317        -6.6  1827220      465      985  20200716  23

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
plt.plot(temp1['x'], temp1['salesAmt'],label='인비저블맨')
plt.plot(temp2['x'], temp2['salesAmt'],label='1917')
plt.title('영화명 "인비저블맨"의 일별 매출액(salesAmt)과 영화명 "1917"의 일별 매출액(salesAmt) 선 그래프')
plt.xlabel('날짜')
plt.ylabel('매출액')
plt.xticks(range(len(dates)),dates, fontsize=6, rotation=90)
plt.legend(loc=1) #범례
plt.show()
