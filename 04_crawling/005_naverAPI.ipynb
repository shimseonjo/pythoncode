# %% [markdown]
# ### 1. 네이버API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
# naver개발자 센터에서 발급받은 client_id,client_secret
client_id = "cdbNpk6dHGSJP8a3NR3i"
client_secret = "eOuTcEChES"
encText = urllib.parse.quote("봄나물")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 30 Mar 2020 12:23:25 +0900",
# "total": 194322,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>봄나물</b> 마늘대무침/풋마늘무침 만드는법 :)",
# "link": "https:\/\/blog.naver.com\/ksh3820?Redirect=Log&logNo=221867020689",
# "description": "<b>봄나물</b> 마늘대무침/풋마늘무침 만드는법 :) 안녕하세요, 달리입니다. 다들 주말 잘 보내고 계신가요?... 저는 나물무칠 때 그런걸 넣어본 적이 없어서 의구심이 들었는데, 넣어보니 확실히 감칠맛이 좋더라구요.... ",
# "bloggername": "달리의 USB",
# "bloggerlink": "https://blog.naver.com/ksh3820",
# "postdate": "20200322"
#
# },
# {
# "title": "향긋한 봄 내음과 함께 찾아오는, <b>봄나물</b> 종류와 효능!",
# "link": "https:\/\/blog.naver.com\/ilovekwater?Redirect=Log&logNo=221824020518",
# "description": "오늘은 봄철 대표적인 <b>나물</b>의 종류와 효능에 대해서 알아보았습니다. 신체가 따뜻해진 계절에 적응하지 못해 피곤하고, 무기력증을 느끼기 쉬운데요. 규칙적인 운동과 향긋한 <b>봄</b> 내음 가득한 식단으로 새로운... ",
# "bloggername": "K-water 공식 블로그 '맛있는 수다(水多)'",
# "bloggerlink": "https://blog.naver.com/ilovekwater",
# "postdate": "20200225"
#
# },
# {
# "title": "면역력 높이는 제철 <b>봄나물</b> 종류",
# "link": "https:\/\/blog.naver.com\/leeandarchi?Redirect=Log&logNo=221863742386",
# "description": "겨울 동안 저하된 면역력을 회복하고 춘곤증을 이기기 위해, 제철 나물, <b>봄나물</b>을 섭취하는 것이 많은 도움이 된다고 합니다. 면역력을 높여주는 <b>봄나물</b>에는 어떤 종류가 있는지 함께 알아보겠습니다.... ",
# "bloggername": "리엔_건축전문블로그",
# "bloggerlink": "https://blog.naver.com/leeandarchi",
# "postdate": "20200321"
#
# },
# {
# "title": "유채나물무침 봄알려주는 <b>봄나물</b>",
# "link": "https:\/\/blog.naver.com\/jimini0_0?Redirect=Log&logNo=221875639357",
# "description": "이때 먹어야지 맛있는 #<b>봄나물</b> [ #유채나물무침 ] 고소~~ 역시나 마찬가지로 지금 아니면 맛이 별로 없을 만한 메뉴를 가지고 왔어요. 이야기했던 것처럼 제철 메뉴가 가장 맛있으므로 가급적이면 지금 현재 가장... ",
# "bloggername": "you are the apple in my eyes",
# "bloggerlink": "https://blog.naver.com/jimini0_0",
# "postdate": "20200327"
#
# },
# {
# "title": "<b>봄나물</b> 종류와 효능 알고 섭취하기",
# "link": "https:\/\/blog.naver.com\/sohon23m?Redirect=Log&logNo=221858668530",
# "description": "마지막 <b>봄나물</b> 종류로는 돌나물이 되겠습니다. 돌나물에는 골다공증에 좋은 효능이 있습니다. 바로 칼슘 덕분인데요. 돌나물에는 우유보다 2배정도 되는 칼슘이 들어있습니다. 이 덕분에, 성장기 아이들이... ",
# "bloggername": "DIY-오디오 앰프 자작",
# "bloggerlink": "https://blog.naver.com/sohon23m",
# "postdate": "20200317"
#
# },
# {
# "title": "방풍나물 무침 제철음식 <b>봄나물</b>로 건강 챙겨요",
# "link": "https:\/\/blog.naver.com\/himchan2015?Redirect=Log&logNo=221835745883",
# "description": "그리고 신경성 스트레스를 완화해주기도 하며 불면증과 피부질환 치료에도 도움을 준다고 하니 향긋한 방풍나물 건강을 위해 꼭 챙겨드셨으면 좋겠습니다 #방풍나물무침 #방풍나물효능 #방풍나물 #<b>봄나물</b>무침... ",
# "bloggername": "달콤제이's Story..♥",
# "bloggerlink": "https://blog.naver.com/himchan2015",
# "postdate": "20200303"
#
# },
# {
# "title": "망초대 <b>봄나물</b>로 인정!",
# "link": "https:\/\/blog.naver.com\/kesi03?Redirect=Log&logNo=221877272114",
# "description": "어떤 <b>봄나물</b>보다 연하고 맛있어서 시금치나물처럼 김밥에 넣어 말아주거나 비빔밥을 만들어줘도 아이들이 너무 맛있게 잘 먹더라구요 ㅎㅎ 또 한가지는 고추장,고춧가루,멸치액젓,통깨,식초,설탕을 넣어... ",
# "bloggername": "케시티에 행복한 하루☆",
# "bloggerlink": "https://blog.naver.com/kesi03",
# "postdate": "20200329"
#
# },
# {
# "title": "이 맛에 봄, <b>봄나물</b>",
# "link": "https:\/\/blog.naver.com\/yh_liebe?Redirect=Log&logNo=221870913356",
# "description": "봄 씀바귀를 먹으면 그 해 여름 더위를 타지 않는다&quot;라는 말이 있을 정도로 효능을 인정받은 <b>봄나물</b>입니... 돌나물 지역에 따라 '돈나물' 혹은 '수근초'라고 부르기도 하는 돌나물은 잎이 아주 연하고 만졌을 때... ",
# "bloggername": "선명이와 하루하루",
# "bloggerlink": "https://blog.naver.com/yh_liebe",
# "postdate": "20200324"
#
# },
# {
# "title": "머위나물 제철 <b>봄나물</b> 머위나물 효능",
# "link": "https:\/\/blog.naver.com\/wjdtj54?Redirect=Log&logNo=221859453797",
# "description": "제철 <b>봄나물</b> #머위나물 은 쌉싸름한 맛이 입맛 돋우는데 최고인 것 같아요 마당 뒤편에 나와있는 머위가 너무 예뻐서 한 컷 찍었어요 머위나물 맛있게 만드는 법 (계량 기준) 1컵=200ml 1 큰 술=1T(1테이블 스푼)... ",
# "bloggername": "스마일로즈& 건강밥상",
# "bloggerlink": "https://blog.naver.com/wjdtj54",
# "postdate": "20200318"
#
# },
# {
# "title": "<b>봄나물</b> 쑥전 만드는법 간단하게 갈아서 쉽게 해봐요",
# "link": "https:\/\/blog.naver.com\/moo4114?Redirect=Log&logNo=221851191804",
# "description": "<b>봄나물</b> 쑥전 만드는법 간단하게 갈아서 쉽게 해봐요 <b>봄나물</b>? 뭔가 향긋하고 영양 가득한 게 건강해지는 기분이 들잖아요!! 해서 요즘 <b>봄나물</b>로 삶아서 반찬도 만들고 겉절이, 국도 끓여 맛있게 봄의 향기를... ",
# "bloggername": "요리가 좋아 여경",
# "bloggerlink": "https://blog.naver.com/moo4114",
# "postdate": "20200313"
#
# }
# ]
# }
