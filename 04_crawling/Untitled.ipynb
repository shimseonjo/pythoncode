# %%
import urllib
import requests
from bs4 import BeautifulSoup

params=urllib.parse.urlencode({'page':1})
url='https://movie.naver.com/movie/point/af/list.nhn?&%s' %params
print(url)

#params={'page':1}
#url='https://movie.naver.com/movie/point/af/list.nhn'
#res=requests.get(url,params=params)
#print(res.content.decode('euc-kr'))

response = urllib.request.urlopen(url)
navigator=BeautifulSoup(response,'html.parser')
table=navigator.find('table',class_='list_netizen')
print(table)

list_records=[]
for i,r in enumerate(table.find_all('tr')):
    for j,c in enumerate(r.find_all('td')):
        if j==0:
            record={'번호':int(c.text.strip())}
        elif j==2:
            record.update({'평점':int(c.text.strip())})
        elif j==3:
            record.update({'영화':str(c.find('a',class_='movie').text.strip())})
            record.update({'140자 평':str(c.text).split('\n')[2]})
        elif j==4:
            record.update({'글쓴이':c.find('a',class_='author').text.strip()})
            record.update({'날짜':str(c.text).split('****')[1]})
    try:
        list_records.append(record)
    except:
        pass

print(list_records)
# Out:
# https://movie.naver.com/movie/point/af/list.nhn?&page=1
# <table cellspacing="0" class="list_netizen">
# <caption class="blind">개봉 후 평점 목록으로 번호, 평점, 내용, 글쓴이, 날짜 정보를 제공</caption>
# <colgroup><col width="44"/><col width="*"/><col width="68"/>
# <thead>
# <tr>
# <th>번호</th>
# <th>감상평</th>
# <th class="al"><span class="th_m1">글쓴이·날짜</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="ac num">16801399</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=167651&amp;target=after">극한직업</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
# </div>
# <br/>내 인생 코미디 영화 정말 웃음이 끊기지 않았던 유일한 영화
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('yewo****', 'OGbX11eIsT0bQIbxV4aEdBWbtCHq6mS+hhsvBiLGdSk=', '내 인생 코미디 영화 정말 웃음이 끊기지 않았던 유일한 영화', '16801399', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801399', 'after');">yewo****</a><br/>20.03.30</td>
# </tr>
# <tr>
# <td class="ac num">16801398</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=179482&amp;target=after">82년생 김지영</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:30%">별점 - 총 10점 중</span></span><em>3</em>
# </div>
# <br/>보기 전엔  페미영화인 줄 알았는데  걍 잔잔하니 볼만 했음..다만  지영이가  미칠 정도의 불평등하고 여자로서 어려운 점이 없어서인지..개연성이 부족했음. 저 정도 가지고 그런 병에 걸리면 우리 어머니 시대 분들은 죄다 정신병원에 가야 함
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('jsy6****', 'wMckPOof4/H3ajrX8wHcnacxF++SmfbVA2Roagyjqt8=', '보기 전엔  페미영화인 줄 알았는데  걍 잔잔하니 볼만 했음..다만  지영이가  미칠 정도의 불평등하고 여자로서 어려운 점이 없어서인지..개연성이 부족했음. 저 정도 가지고 그런 병에 걸리면 우리 어머니 시대 분들은 죄다 정신병원에 가야 함', '16801398', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801398', 'after');">jsy6****</a><br/>20.03.30</td>
# </tr>
# <tr>
# <td class="ac num">16801397</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=126032&amp;target=after">수어사이드 스쿼드</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:60%">별점 - 총 10점 중</span></span><em>6</em>
# </div>
# <br/>마고 로비 아니였음 1점
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('libi****', 'ZifVsN6bdBGUOQ8PZpjUHW1oYhgRk5okzNcJAG1GHCc=', '마고 로비 아니였음 1점', '16801397', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801397', 'after');">libi****</a><br/>20.03.30</td>
# </tr>
# <tr>
# <td class="ac num">16801396</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=189028&amp;target=after">울프 콜</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:80%">별점 - 총 10점 중</span></span><em>8</em>
# </div>
# <br/>오랜만에 나온 볼만한 잠수함 영화할리우드식의 극적인 연출은 없지만 담백하게 묘사해서 오히려 더 기억에 남을거 같아요
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('eden****', 'WBo/wIf2rgYpHV1D6PuX047cF8kYcXWswgpoBHijByg=', '오랜만에 나온 볼만한 잠수함 영화할리우드식의 극적인 연출은 없지만 담백하게 묘사해서 오히려 더 기억에 남을거 같아요', '16801396', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801396', 'after');">eden****</a><br/>20.03.30</td>
# </tr>
# <tr>
# <td class="ac num">16801395</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=19128&amp;target=after">뮬란</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
# </div>
# <br/>짱이에요
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('look****', 'aI3zccbMLbnzHReMUIhp/wPQKMWxn8OmL/WRjDFCrfA=', '짱이에요', '16801395', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801395', 'after');">look****</a><br/>20.03.30</td>
# </tr>
# <tr>
# <td class="ac num">16801394</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=52555&amp;target=after">조디악</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:70%">별점 - 총 10점 중</span></span><em>7</em>
# </div>
# <br/>.
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('moon****', 'IkXej0xW3DWLPnvwZkfO/XEKv3ofUckNsWEEY7CczKM=', '.', '16801394', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801394', 'after');">moon****</a><br/>20.03.30</td>
# </tr>
# <tr>
# <td class="ac num">16801393</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=64686&amp;target=after">소셜 네트워크</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:60%">별점 - 총 10점 중</span></span><em>6</em>
# </div>
# <br/>스토리가 뛰어남과 동시에 지루함도 뛰어난다
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('libi****', 'E3vK0ISkeuAs3FUSZMXSpglkYiWF5Cm/eTD616mq/vw=', '스토리가 뛰어남과 동시에 지루함도 뛰어난다', '16801393', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801393', 'after');">libi****</a><br/>20.03.30</td>
# </tr>
# <tr>
# <td class="ac num">16801392</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=69989&amp;target=after">토르: 천둥의 신</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:80%">별점 - 총 10점 중</span></span><em>8</em>
# </div>
# <br/>어벤져스 직전까진 별로 흥미롭지 못했던
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('libi****', '0QK5MvHS/Sl/5fA0kbfSAmPApjac0eBuum4Hyud+GB4=', '어벤져스 직전까진 별로 흥미롭지 못했던', '16801392', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801392', 'after');">libi****</a><br/>20.03.30</td>
# </tr>
# <tr>
# <td class="ac num">16801391</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=123630&amp;target=after">트랜스포머: 최후의 기사</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:10%">별점 - 총 10점 중</span></span><em>1</em>
# </div>
# <br/>오토봇들이 사이버트론 박살 냈으면서 지들이 성을 내고 마이클 베이 영화답게 폭발이 많이 나타나지만  1편에서 부터 본 폭발 장면에는 이제는 질림 그리고 나는 갈바트론과 싸우는 것을 기대했는데 갈바트론은 왜 메가트론으로  돼어 있음?
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('epro****', 'gaVjpCO0yvXKf3WsQ7i0PhSzqW3kG5LhHmLyx4rshVw=', '오토봇들이 사이버트론 박살 냈으면서 지들이 성을 내고 마이클 베이 영화답게 폭발이 많이 나타나지만  1편에서 부터 본 폭발 장면에는 이제는 질림 그리고 나는 갈바트론과 싸우는 것을 기대했는데 갈바트론은 왜 메가트론으로  돼어 있음? ', '16801391', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801391', 'after');">epro****</a><br/>20.03.30</td>
# </tr>
# <tr>
# <td class="ac num">16801389</td>
# <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=167600&amp;target=after">사랑하고 있습니까</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
# </div>
# <br/>
# <a class="report" href="javascript:report('cham****', 'vAPs/3dBiJJRct4rOQJUo/EEGIUWC+DOgAAv4Z3yeoA=', '', '16801389', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>
# <td class="num"><a class="author" href="javascript:find_list('nickname','16801389', 'after');">cham****</a><br/>20.03.30</td>
# </tr>
# </tbody>
# </colgroup></table>
# ValueErrorTraceback (most recent call last)
# <ipython-input-1-564e3e2a1436> in <module>
#      23             record={'번호':int(c.text.strip())}
#      24         elif j==2:
# ---> 25             record.update({'평점':int(c.text.strip())})
#      26         elif j==3:
#      27             record.update({'영화':str(c.find('a',class_='movie').text.strip())})
#
# ValueError: invalid literal for int() with base 10: 'yewo****20.03.30'
