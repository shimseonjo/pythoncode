# %%
import pandas  as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ##### 1. 주민등록인구및세대현황.csv 가지고 와서 데이터 프레임으로 작성합니다.

# %%
df = pd.read_csv('주민등록인구및세대현황.csv', encoding="cp949")

# %%
df
# Out:
#                               행정구역 2020년06월_총인구수 2020년06월_세대수  \
# 0              서울특별시  (1100000000)     9,720,846    4,384,076
# 1           서울특별시 종로구 (1111000000)       150,383       74,497
# 2      서울특별시 종로구 청운효자동(1111051500)        12,609        5,395
# 3        서울특별시 종로구 사직동(1111053000)         9,506        4,717
# 4        서울특별시 종로구 삼청동(1111054000)         2,707        1,370
# ...                            ...           ...          ...
# 3818  제주특별자치도 서귀포시 서홍동(5013058000)        10,416        4,259
# 3819  제주특별자치도 서귀포시 대륜동(5013059000)        14,514        6,342
# 3820  제주특별자치도 서귀포시 대천동(5013060000)        13,820        6,258
# 3821  제주특별자치도 서귀포시 중문동(5013061000)        11,515        5,439
# 3822  제주특별자치도 서귀포시 예래동(5013062000)         3,935        1,950
#
#       2020년06월_세대당 인구 2020년06월_남자 인구수 2020년06월_여자 인구수  2020년06월_남여 비율
# 0                2.22       4,732,275       4,988,571            0.95
# 1                2.02          73,288          77,095            0.95
# 2                2.34           5,885           6,724            0.88
# 3                2.02           4,281           5,225            0.82
# 4                1.98           1,301           1,406            0.93
# ...               ...             ...             ...             ...
# 3818             2.45           5,160           5,256            0.98
# 3819             2.29           7,359           7,155            1.03
# 3820             2.21           7,011           6,809            1.03
# 3821             2.12           5,926           5,589            1.06
# 3822             2.02           2,041           1,894            1.08
#
# [3823 rows x 7 columns]

# %% [markdown]
# ##### 2. 인구정보 데이터 프레임의 컬럼명을 행정구역, 총인구수, 세대수, 세대당인구, 남자, 여자, 남녀비율 로 변경하세요

# %%
df.columns = ["행정구역", "총인구수", "세대수", "세대당인구", "남자", "여자", "남녀비율"]

# %%
df
# Out:
#                               행정구역       총인구수        세대수  세대당인구         남자  \
# 0              서울특별시  (1100000000)  9,720,846  4,384,076   2.22  4,732,275
# 1           서울특별시 종로구 (1111000000)    150,383     74,497   2.02     73,288
# 2      서울특별시 종로구 청운효자동(1111051500)     12,609      5,395   2.34      5,885
# 3        서울특별시 종로구 사직동(1111053000)      9,506      4,717   2.02      4,281
# 4        서울특별시 종로구 삼청동(1111054000)      2,707      1,370   1.98      1,301
# ...                            ...        ...        ...    ...        ...
# 3818  제주특별자치도 서귀포시 서홍동(5013058000)     10,416      4,259   2.45      5,160
# 3819  제주특별자치도 서귀포시 대륜동(5013059000)     14,514      6,342   2.29      7,359
# 3820  제주특별자치도 서귀포시 대천동(5013060000)     13,820      6,258   2.21      7,011
# 3821  제주특별자치도 서귀포시 중문동(5013061000)     11,515      5,439   2.12      5,926
# 3822  제주특별자치도 서귀포시 예래동(5013062000)      3,935      1,950   2.02      2,041
#
#              여자  남녀비율
# 0     4,988,571  0.95
# 1        77,095  0.95
# 2         6,724  0.88
# 3         5,225  0.82
# 4         1,406  0.93
# ...         ...   ...
# 3818      5,256  0.98
# 3819      7,155  1.03
# 3820      6,809  1.03
# 3821      5,589  1.06
# 3822      1,894  1.08
#
# [3823 rows x 7 columns]

# %% [markdown]
# ##### 3. 남녀비율 컬럼을 제거합니다.

# %%
df = df.drop('남녀비율', axis=1)

# %%
df
# Out:
#                               행정구역       총인구수        세대수  세대당인구         남자  \
# 0              서울특별시  (1100000000)  9,720,846  4,384,076   2.22  4,732,275
# 1           서울특별시 종로구 (1111000000)    150,383     74,497   2.02     73,288
# 2      서울특별시 종로구 청운효자동(1111051500)     12,609      5,395   2.34      5,885
# 3        서울특별시 종로구 사직동(1111053000)      9,506      4,717   2.02      4,281
# 4        서울특별시 종로구 삼청동(1111054000)      2,707      1,370   1.98      1,301
# ...                            ...        ...        ...    ...        ...
# 3818  제주특별자치도 서귀포시 서홍동(5013058000)     10,416      4,259   2.45      5,160
# 3819  제주특별자치도 서귀포시 대륜동(5013059000)     14,514      6,342   2.29      7,359
# 3820  제주특별자치도 서귀포시 대천동(5013060000)     13,820      6,258   2.21      7,011
# 3821  제주특별자치도 서귀포시 중문동(5013061000)     11,515      5,439   2.12      5,926
# 3822  제주특별자치도 서귀포시 예래동(5013062000)      3,935      1,950   2.02      2,041
#
#              여자
# 0     4,988,571
# 1        77,095
# 2         6,724
# 3         5,225
# 4         1,406
# ...         ...
# 3818      5,256
# 3819      7,155
# 3820      6,809
# 3821      5,589
# 3822      1,894
#
# [3823 rows x 6 columns]

# %% [markdown]
# ##### 4. 행정구역 컬럼의 ‘(’ ‘)’를 제거하고 시,구,동 컬럼을 만들어 분리해 넣고 대구지역의 값만 가지고 와서 인덱스를 새로 부여합니다.

# %%
df['시'] = df['행정구역'].str.split(' ').str[0]
df['구'] = df['행정구역'].str.split(' ').str[1]
df['동'] = df['행정구역'].str.split(' ').str[2].str.split('(').str[0]

# %%
df = df[df['시'] == '대구광역시']
df = df.reset_index(drop=True)

# %%
df
# Out:
#                           행정구역       총인구수        세대수  세대당인구         남자  \
# 0          대구광역시  (2700000000)  2,427,954  1,046,585   2.32  1,198,815
# 1        대구광역시 중구 (2711000000)     76,984     38,954   1.98     37,036
# 2     대구광역시 중구 동인동(2711051700)      8,755      5,183   1.69      4,341
# 3     대구광역시 중구 삼덕동(2711054500)      6,733      4,018   1.68      3,186
# 4    대구광역시 중구 성내1동(2711056500)      5,033      3,349   1.50      2,394
# ..                         ...        ...        ...    ...        ...
# 145  대구광역시 달성군 옥포읍(2771026200)     25,236     10,907   2.31     12,774
# 146  대구광역시 달성군 현풍읍(2771026500)     23,509     11,775   2.00     12,263
# 147  대구광역시 달성군 가창면(2771031000)      8,041      3,754   2.14      4,004
# 148  대구광역시 달성군 하빈면(2771033000)      3,725      2,025   1.84      2,014
# 149  대구광역시 달성군 구지면(2771038000)      9,514      4,775   1.99      5,104
#
#             여자      시    구     동
# 0    1,229,139  대구광역시
# 1       39,948  대구광역시   중구
# 2        4,414  대구광역시   중구   동인동
# 3        3,547  대구광역시   중구   삼덕동
# 4        2,639  대구광역시   중구  성내1동
# ..         ...    ...  ...   ...
# 145     12,462  대구광역시  달성군   옥포읍
# 146     11,246  대구광역시  달성군   현풍읍
# 147      4,037  대구광역시  달성군   가창면
# 148      1,711  대구광역시  달성군   하빈면
# 149      4,410  대구광역시  달성군   구지면
#
# [150 rows x 9 columns]

# %% [markdown]
# ##### 5. 총인구수, 남자, 여자 컬럼의 데이타 타입을 정수형으로 변경합니다.

# %%
df['총인구수'] = df['총인구수'].str.replace(',', '').astype('int64')
df['남자'] = df['남자'].str.replace(',', '').astype('int64')
df['여자'] = df['여자'].str.replace(',', '').astype('int64')

# %%
# Out:
# 0      1198815
# 1        37036
# 2         4341
# 3         3186
# 4         2394
#         ...
# 145      12774
# 146      12263
# 147       4004
# 148       2014
# 149       5104
# Name: 남자, Length: 150, dtype: int64

# %% [markdown]
# ##### 6. 구별로 대구 인구를 차트로 표시합니다.

# %%
plt.bar(df['구'], df['총인구수'])
plt.show()

# %% [markdown]
# ##### 7. 동별 남,여 인구를 차트로 표시합니다.

# %%
plt.bar(df['구'], df['남자'], color='b', label='male')
plt.show()
plt.bar(df['구'], df['여자'], color='r', label='female')
plt.show()

# %% [markdown]
# ##### 8. Choropleth, geojson 등을 이용하여 동별 인구수를 색상별로 지도에 나타내시오

# %%
import folium,json

map_osm = folium.Map(location=[35.848987,128.72818],zoom_start=10)
with open('daegu_1.json') as json_file:
    json_data = json.load(json_file)
    folium.GeoJson(json_data, name='geojson').add_to(map_osm)
    bins = list(df['총인구수'].quantile([0, 0.25, 0.5, 0.75, 1]
    folium.Choropleth(geo_data=json_data, 
            data=df, 
            columns=['구','총인구수'], 
            key_on='feature.properties.name',
            bins=bins,
            fill_color='YlGn', 
            fill_opacity =0.7,
            line_opacity = 0.3,
).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7f17b7f6b6984e17a998cde4afb0a61f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7f17b7f6b6984e17a998cde4afb0a61f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7f17b7f6b6984e17a998cde4afb0a61f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7f17b7f6b6984e17a998cde4afb0a61f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
